# %% [markdown]
# ## Parse data

# %%
import warnings
from typing import List
import math

import pandas as pd
from glob import glob

# import re
from bs4 import BeautifulSoup

warnings.filterwarnings("ignore", category=DeprecationWarning)

# Get a list of all xlsx files
files = sorted(glob("../typedb-schema-and-data/CPs exp 2a data/*.xlsx"))

data = {}


def change_class_name(class_name: str) -> str:
    """Change the class name to a more readable format.

    Args:
        class_name (str): The class name to be changed.

    Returns:
        str: The changed class name.

    """
    return {
        "agents": "actor",
        "objects": "object",
        "actions": "action",
        "locations": "location",
    }[class_name]


print(f"number of files (participants): {len(files)}\n")
# Loop through the list of files and read each file
for file in files:
    print(f"processing `{file}` ...")

    participant = file.split("/")[-1].split("_")[0]

    dataframe = pd.read_excel(file)
    dataframe.drop_duplicates(subset="name", keep="last", inplace=True)
    # Now you can do something with the data
    assert len(dataframe.situation) == len(dataframe.actions)
    print(
        f"There are in total of {len(dataframe.situation)} situation-action pairs "
        f"in the file {file}, \nparticipant number: {participant}\n"
    )

    situations = []
    actions = []
    data[participant] = []
    for situation, action in zip(dataframe.situation, dataframe.actions):
        # Parse HTML content
        situation_parsed = []

        if isinstance(situation, float) and math.isnan(situation):
            situation_parsed = None

        else:
            soup = BeautifulSoup(situation, "html.parser")

            # Extract data
            for div in soup.find_all("div", class_="item"):
                # Extract class and text content

                class_name = (
                    div.get("class")[1]
                    if len(div.get("class")) > 1
                    else div.get("class")[0]
                )
                # Process the text content more carefully to add spaces around buttons
                # or special divs
                texts = div.find_all(text=True)
                text_content = " ".join(text.strip() for text in texts).strip().lower()
                if class_name != "counters":  # we don't use this anymore
                    situation_parsed.append(
                        [change_class_name(class_name), text_content]
                    )

        situations.append(situation_parsed)

        soup = BeautifulSoup(action, "html.parser")
        action_parsed = {}

        # Extract boxes
        boxes = soup.find_all("div", class_="box box_action")

        for box in boxes:
            box_id = box.get("id")
            action_parsed[box_id] = []

            items = box.find_all("div", class_="item")
            for item in items:
                class_name = (
                    item.get("class")[1]
                    if len(item.get("class")) > 1
                    else item.get("class")[0]
                )
                # Process the text content more carefully to add spaces around buttons
                # or special divs
                texts = item.find_all(text=True)
                text_content = " ".join(text.strip() for text in texts).strip().lower()
                if class_name != "counters":  # we don't use this anymore
                    action_parsed[box_id].append(
                        [change_class_name(class_name), text_content]
                    )

        actions.append(action_parsed)
        assert len(situations) == len(actions)
        data[participant].append(
            {"situation": situation_parsed, "what_we_do": action_parsed}
        )

    # data[participant] = list(zip(situations, actions))
# Out:
# number of files (participants): 10
#
# processing `../typedb-schema-and-data/CPs exp 2a data/p01_interaction_patterns.xlsx` ...
# There are in total of 14 situation-action pairs in the file ../typedb-schema-and-data/CPs exp 2a data/p01_interaction_patterns.xlsx,
# participant number: p01
#
# processing `../typedb-schema-and-data/CPs exp 2a data/p03_interaction_patterns.xlsx` ...
# There are in total of 15 situation-action pairs in the file ../typedb-schema-and-data/CPs exp 2a data/p03_interaction_patterns.xlsx,
# participant number: p03
#
# processing `../typedb-schema-and-data/CPs exp 2a data/p04_interaction_patterns.xlsx` ...
# There are in total of 13 situation-action pairs in the file ../typedb-schema-and-data/CPs exp 2a data/p04_interaction_patterns.xlsx,
# participant number: p04
#
# processing `../typedb-schema-and-data/CPs exp 2a data/p05_interaction_patterns.xlsx` ...
# There are in total of 14 situation-action pairs in the file ../typedb-schema-and-data/CPs exp 2a data/p05_interaction_patterns.xlsx,
# participant number: p05
#
# processing `../typedb-schema-and-data/CPs exp 2a data/p06_interaction_patterns.xlsx` ...
# There are in total of 13 situation-action pairs in the file ../typedb-schema-and-data/CPs exp 2a data/p06_interaction_patterns.xlsx,
# participant number: p06
#
# processing `../typedb-schema-and-data/CPs exp 2a data/p07_interaction_patterns.xlsx` ...
# There are in total of 23 situation-action pairs in the file ../typedb-schema-and-data/CPs exp 2a data/p07_interaction_patterns.xlsx,
# participant number: p07
#
# processing `../typedb-schema-and-data/CPs exp 2a data/p09_interaction_patterns.xlsx` ...
# There are in total of 14 situation-action pairs in the file ../typedb-schema-and-data/CPs exp 2a data/p09_interaction_patterns.xlsx,
# participant number: p09
#
# processing `../typedb-schema-and-data/CPs exp 2a data/p13_interaction_patterns.xlsx` ...
# There are in total of 10 situation-action pairs in the file ../typedb-schema-and-data/CPs exp 2a data/p13_interaction_patterns.xlsx,
# participant number: p13
#
# processing `../typedb-schema-and-data/CPs exp 2a data/p14_interaction_patterns.xlsx` ...
# There are in total of 28 situation-action pairs in the file ../typedb-schema-and-data/CPs exp 2a data/p14_interaction_patterns.xlsx,
# participant number: p14
#
# processing `../typedb-schema-and-data/CPs exp 2a data/p15_interaction_patterns.xlsx` ...
# There are in total of 23 situation-action pairs in the file ../typedb-schema-and-data/CPs exp 2a data/p15_interaction_patterns.xlsx,
# participant number: p15

# %% [markdown]
# ## Make the data a bit more explainable

# %%
data_better = {}
weird = []
participants = sorted(list(data.keys()))

for participant_id, data_list in data.items():

    data_better[participant_id] = []
    for i, data_dict in enumerate(data_list):

        human_macro_actions, robot_macro_actions = [], []
        for box_id, list_of_tuples in data_dict["what_we_do"].items():
            if ["actor", "robot"] in list_of_tuples:
                robot_macro_actions.append(list_of_tuples)
            elif ["actor", "human"] in list_of_tuples:
                human_macro_actions.append(list_of_tuples)
            else:
                weird.append(list_of_tuples)

        data_better[participant_id].append(
            {
                "situation_graph": data_dict["situation"],
                "human_action_graph": human_macro_actions,
                "robot_action_graph": robot_macro_actions,
            }
        )
data = data_better

# %%
for participant_id, list_ in data.items():
    print(f"Participant {participant_id}")
    for i, data_dict in enumerate(list_):
        print(f"Situation {i:02}")
        print(f"Situation graph: {data_dict['situation_graph']}")
        print(f"Human action graphs: {data_dict['human_action_graph']}")
        print(f"Robot action graphs: {data_dict['robot_action_graph']}")
        print()
# Out:
# Participant p01
# Situation 00
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock'], ['location', 'bottom of rock pile'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'move to object'], ['object', 'large rock']], [['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to object'], ['object', 'large rock']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'right side of rock pile']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'bottom of rock pile']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']]]
#
# Situation 01
# Situation graph: [['object', 'small rock'], ['location', 'top of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'move back and forth in location'], ['location', 'top of rock pile']], [['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to object'], ['object', 'small rock']]]
#
# Situation 02
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock'], ['location', 'top of rock pile'], ['object', 'small rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'right side of rock pile']]]
#
# Situation 03
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock'], ['location', 'left side of rock pile'], ['object', 'large rock'], ['location', 'right side of rock pile'], ['object', 'large rock'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'move to object'], ['object', 'large rock']], [['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'right side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to object'], ['object', 'large rock']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'right side of rock pile']]]
#
# Situation 04
# Situation graph: [['location', 'bottom of rock pile'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['location', 'bottom of rock pile'], ['object', 'small rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'bottom of rock pile']], [['actor', 'robot'], ['action', 'move to object'], ['object', 'small rock']]]
#
# Situation 05
# Situation graph: [['location', 'left side of rock pile'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim'], ['object', 'small rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock']]]
#
# Situation 06
# Situation graph: [['location', 'on top of object'], ['object', 'small rock'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'bottom of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock']]]
#
# Situation 07
# Situation graph: [['object', 'small rock'], ['location', 'top of rock pile'], ['location', 'top of rock pile'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock']], [['actor', 'robot'], ['action', 'move to actor'], ['actor', 'victim']]]
#
# Situation 08
# Situation graph: [['location', 'top of rock pile'], ['object', 'small rock'], ['location', 'on top of object'], ['object', 'small rock'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock']]]
#
# Situation 09
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock'], ['object', 'small rock'], ['location', 'bottom of rock pile'], ['object', 'small rock'], ['location', 'on top of actor'], ['object', 'small rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of field']], [['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
#
# Situation 10
# Situation graph: [['location', 'left side of rock pile'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'move to object'], ['object', 'large rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to object'], ['object', 'large rock']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock']]]
#
# Situation 11
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
#
# Situation 12
# Situation graph: [['location', 'left side of rock pile'], ['object', 'large rock'], ['location', 'left side of field'], ['object', 'small rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['location', 'left side of rock pile'], ['action', 'pick up object in location'], ['actor', 'robot'], ['object', 'large rock']]]
#
# Situation 13
# Situation graph: [['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'move to object'], ['object', 'large rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to object'], ['object', 'large rock']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock']]]
#
# Participant p03
# Situation 00
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock'], ['location', 'top of rock pile'], ['object', 'small rock']]
# Human action graphs: [[['actor', 'human'], ['object', 'small rock'], ['action', 'pick up object in location']]]
# Robot action graphs: [[['actor', 'robot'], ['object', 'large rock'], ['action', 'break object in location']], [['actor', 'robot'], ['object', 'large rock'], ['action', 'break object in location']], [['actor', 'robot'], ['actor', 'human'], ['object', 'small rock'], ['action', 'pick up object in location']]]
#
# Situation 01
# Situation graph: [['object', 'small rock'], ['location', 'top of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location']]]
#
# Situation 02
# Situation graph: None
# Human action graphs: []
# Robot action graphs: []
#
# Situation 03
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock'], ['location', 'top of rock pile'], ['object', 'small rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock']]]
#
# Situation 04
# Situation graph: [['location', 'left side of rock pile'], ['object', 'large rock'], ['location', 'left side of rock pile'], ['object', 'small rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock']]]
#
# Situation 05
# Situation graph: [['location', 'bottom of rock pile'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'bottom of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock']]]
#
# Situation 06
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock'], ['location', 'left side of rock pile'], ['object', 'small rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile'], ['location', 'left side of rock pile']]]
#
# Situation 07
# Situation graph: [['location', 'left side of rock pile'], ['object', 'large rock'], ['location', 'on top of actor'], ['object', 'small rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['location', 'on top of actor']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']]]
#
# Situation 08
# Situation graph: [['location', 'left side of rock pile'], ['object', 'small rock'], ['location', 'top of rock pile'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']]]
#
# Situation 09
# Situation graph: [['location', 'top of rock pile'], ['object', 'small rock'], ['location', 'top of rock pile'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
# Robot action graphs: [[['actor', 'robot'], ['object', 'large rock'], ['location', 'top of rock pile'], ['action', 'pick up object in location']]]
#
# Situation 10
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock'], ['location', 'top of rock pile'], ['object', 'small rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
#
# Situation 11
# Situation graph: [['location', 'top of rock pile'], ['object', 'small rock'], ['location', 'top of rock pile'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile'], ['location', 'on top of actor'], ['actor', 'victim']]]
#
# Situation 12
# Situation graph: [['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'stand still in location'], ['location', 'on top of actor'], ['actor', 'victim']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
#
# Situation 13
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock'], ['location', 'bottom of rock pile'], ['object', 'small rock'], ['location', 'bottom of rock pile'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['location', 'bottom of rock pile'], ['object', 'small rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'pick up object in location'], ['location', 'bottom of rock pile'], ['object', 'large rock']]]
#
# Situation 14
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'stand still in location'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
#
# Participant p04
# Situation 00
# Situation graph: [['object', 'large rock'], ['object', 'small rock'], ['location', 'top of rock pile']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location']], [['actor', 'robot'], ['action', 'pick up object in location']]]
#
# Situation 01
# Situation graph: [['object', 'small rock'], ['location', 'top of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location']]]
# Robot action graphs: []
#
# Situation 02
# Situation graph: [['object', 'large rock'], ['object', 'small rock'], ['location', 'top of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile']]]
#
# Situation 03
# Situation graph: [['object', 'large rock']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
#
# Situation 04
# Situation graph: [['object', 'small rock'], ['location', 'bottom of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'bottom of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move back and forth in location'], ['location', 'left side of field']]]
#
# Situation 05
# Situation graph: [['object', 'large rock'], ['location', 'on top of object'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'move back and forth in location'], ['location', 'right side of field']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'on top of object'], ['object', 'large rock']], [['actor', 'robot'], ['action', 'move back and forth in location'], ['location', 'right side of field']], [['actor', 'robot'], ['action', 'stand still in location'], ['location', 'right side of field']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'large rock']]]
#
# Situation 06
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
#
# Situation 07
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile'], ['object', 'small rock'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']], [['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
#
# Situation 08
# Situation graph: [['object', 'small rock'], ['object', 'large rock'], ['location', 'top of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
# Robot action graphs: []
#
# Situation 09
# Situation graph: [['object', 'large rock'], ['location', 'top of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'above rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'move back and forth in location'], ['location', 'right side of field']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
#
# Situation 10
# Situation graph: [['object', 'large rock'], ['location', 'top of rock pile'], ['object', 'small rock'], ['location', 'left side of rock pile'], ['object', 'small rock'], ['location', 'bottom of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']]]
#
# Situation 11
# Situation graph: [['object', 'large rock'], ['location', 'top of rock pile'], ['object', 'small rock'], ['location', 'bottom of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'bottom of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'above rock pile']]]
#
# Situation 12
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
#
# Participant p05
# Situation 00
# Situation graph: [['object', 'large rock'], ['location', 'top of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'move to object'], ['object', 'large rock'], ['location', 'top of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to object'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['actor', 'human'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']]]
#
# Situation 01
# Situation graph: [['location', 'top of rock pile'], ['object', 'small rock'], ['actor', 'human']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'left side of field']]]
# Robot action graphs: []
#
# Situation 02
# Situation graph: [['object', 'large rock'], ['object', 'small rock'], ['location', 'top of rock pile'], ['actor', 'human'], ['actor', 'robot']]
# Human action graphs: [[['actor', 'human'], ['object', 'small rock'], ['location', 'top of rock pile']], [['action', 'drop object in location'], ['actor', 'human'], ['object', 'small rock'], ['location', 'left side of field']]]
# Robot action graphs: [[['actor', 'robot'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'drop object in location'], ['location', 'left side of field'], ['object', 'large rock']]]
#
# Situation 03
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile'], ['actor', 'human'], ['actor', 'robot']]
# Human action graphs: [[['actor', 'human'], ['action', 'move back and forth in location'], ['location', 'left side of rock pile'], ['object', 'large rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to object'], ['object', 'large rock'], ['location', 'left side of rock pile']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']], [['actor', 'human'], ['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']], [['actor', 'human'], ['actor', 'robot'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'left side of field']]]
#
# Situation 04
# Situation graph: [['object', 'small rock'], ['location', 'left side of rock pile'], ['location', 'bottom of rock pile'], ['actor', 'human'], ['actor', 'robot']]
# Human action graphs: [[['actor', 'human'], ['object', 'small rock'], ['action', 'pick up object in location'], ['location', 'left side of rock pile']], [['actor', 'human'], ['object', 'small rock'], ['action', 'drop object in location'], ['location', 'left side of field']]]
# Robot action graphs: [[['actor', 'robot'], ['object', 'small rock'], ['action', 'pick up object in location']], [['actor', 'robot'], ['object', 'small rock'], ['action', 'move back and forth in location']]]
#
# Situation 05
# Situation graph: [['object', 'large rock'], ['object', 'brown rock'], ['location', 'left side of rock pile'], ['location', 'top of rock pile'], ['actor', 'robot']]
# Human action graphs: [[['actor', 'human'], ['action', 'move back and forth in location'], ['location', 'right side of field']], [['actor', 'human'], ['object', 'small rock'], ['action', 'pick up object in location'], ['location', 'left side of rock pile']], [['actor', 'human'], ['object', 'small rock'], ['action', 'drop object in location'], ['location', 'left side of field']], [['actor', 'human'], ['action', 'move back and forth in location'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'drop object in location'], ['object', 'large rock'], ['location', 'right side of field']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'large rock'], ['location', 'right side of field']]]
#
# Situation 06
# Situation graph: [['location', 'top of rock pile'], ['location', 'left side of rock pile'], ['object', 'large rock'], ['actor', 'robot'], ['actor', 'human']]
# Human action graphs: [[['actor', 'human'], ['action', 'move to object'], ['location', 'above rock pile'], ['location', 'on top of object'], ['object', 'large rock']], [['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'left side of field']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to object'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']]]
#
# Situation 07
# Situation graph: [['location', 'left side of rock pile'], ['object', 'small rock'], ['object', 'large rock'], ['actor', 'human'], ['actor', 'robot']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'left side of field']], [['actor', 'human'], ['action', 'move to location'], ['location', 'bottom of rock pile']], [['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'bottom of rock pile']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'left side of field']], [['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']], [['actor', 'human'], ['object', 'small rock'], ['action', 'drop object in location'], ['location', 'left side of field']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to actor'], ['actor', 'human']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'human']], [['actor', 'human'], ['action', 'move to location'], ['location', 'top of rock pile'], ['actor', 'robot']]]
#
# Situation 08
# Situation graph: [['object', 'small rock'], ['object', 'large rock'], ['actor', 'robot'], ['actor', 'human'], ['actor', 'victim'], ['location', 'top of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to location'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['object', 'large rock'], ['action', 'move to actor'], ['actor', 'human']]]
#
# Situation 09
# Situation graph: [['object', 'large rock'], ['object', 'small rock'], ['actor', 'human'], ['actor', 'robot'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'move to location'], ['location', 'left side of rock pile']], [['actor', 'human'], ['action', 'stand still in location'], ['object', 'large rock'], ['location', 'on top of object'], ['location', 'left side of rock pile']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'left side of field']], [['actor', 'human'], ['action', 'stand still in location'], ['location', 'left side of rock pile'], ['object', 'small rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to location'], ['location', 'left side of rock pile']], [['object', 'large rock'], ['actor', 'robot'], ['action', 'break object in location'], ['location', 'left side of rock pile']], [['actor', 'robot'], ['action', 'move to actor'], ['actor', 'human']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
#
# Situation 10
# Situation graph: [['object', 'small rock'], ['object', 'large rock'], ['location', 'top of rock pile'], ['actor', 'robot'], ['actor', 'human']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'bottom of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['actor', 'human'], ['action', 'drop object in location'], ['object', 'large rock'], ['object', 'small rock'], ['location', 'left side of field']], [['actor', 'robot'], ['object', 'small rock'], ['location', 'top of rock pile'], ['action', 'pick up object in location']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'right side of field']]]
#
# Situation 11
# Situation graph: [['object', 'large rock'], ['actor', 'human'], ['location', 'bottom of rock pile'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'move to object'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']], [['actor', 'human'], ['action', 'stand still in location'], ['location', 'on top of object'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to actor'], ['actor', 'human']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
#
# Situation 12
# Situation graph: [['object', 'small rock'], ['location', 'left side of rock pile'], ['actor', 'human'], ['actor', 'robot']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'bottom of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'human'], ['actor', 'robot'], ['action', 'drop object in location'], ['object', 'large rock'], ['object', 'small rock'], ['location', 'left side of field']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'large rock'], ['location', 'right side of field']]]
#
# Situation 13
# Situation graph: [['object', 'large rock'], ['actor', 'human'], ['actor', 'robot'], ['location', 'bottom of rock pile'], ['location', 'left side of rock pile']]
# Human action graphs: [[['object', 'large rock'], ['actor', 'human'], ['action', 'move back and forth in location'], ['location', 'on top of object'], ['location', 'bottom of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to actor'], ['actor', 'human']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'bottom of rock pile']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'large rock'], ['location', 'right side of field']]]
#
# Participant p06
# Situation 00
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'move to object'], ['object', 'small rock']]]
#
# Situation 01
# Situation graph: [['object', 'small rock'], ['location', 'top of rock pile']]
# Human action graphs: [[['actor', 'human'], ['object', 'small rock'], ['action', 'pick up object in location'], ['location', 'left side of field']], [['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']]]
# Robot action graphs: []
#
# Situation 02
# Situation graph: [['object', 'large rock'], ['object', 'small rock'], ['actor', 'robot'], ['actor', 'human'], ['location', 'above rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock']], [['actor', 'human'], ['actor', 'robot'], ['action', 'move to object'], ['location', 'left side of field']]]
#
# Situation 03
# Situation graph: [['object', 'small rock'], ['location', 'bottom of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'bottom of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move back and forth in location'], ['location', 'left side of field']]]
#
# Situation 04
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'move to object'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']], [['actor', 'human'], ['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']], [['actor', 'robot'], ['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'right side of field']]]
#
# Situation 05
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile'], ['object', 'small rock'], ['location', 'bottom of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['action', 'move to object'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']], [['actor', 'robot'], ['action', 'move to object'], ['object', 'small rock'], ['action', 'drop object in location'], ['location', 'left side of rock pile']]]
#
# Situation 06
# Situation graph: [['object', 'small rock'], ['location', 'bottom of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'bottom of rock pile']], [['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'above rock pile']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'right side of field']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['location', 'above rock pile'], ['object', 'large rock']]]
#
# Situation 07
# Situation graph: [['object', 'small rock'], ['object', 'large rock'], ['location', 'on top of object'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'on top of object'], ['actor', 'victim']]]
# Robot action graphs: [[['actor', 'robot'], ['object', 'large rock'], ['action', 'pick up object in location']], [['actor', 'robot'], ['action', 'drop object in location'], ['location', 'on top of object'], ['actor', 'victim']]]
#
# Situation 08
# Situation graph: [['location', 'left side of rock pile'], ['object', 'large rock'], ['object', 'small rock'], ['actor', 'robot'], ['actor', 'human'], ['action', 'break object in location']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'left side of field']], [['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock']], [['actor', 'human'], ['action', 'drop object in location'], ['location', 'left side of field'], ['object', 'small rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
#
# Situation 09
# Situation graph: [['object', 'small rock'], ['actor', 'human'], ['actor', 'robot'], ['location', 'left side of field'], ['location', 'right side of field']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'right side of field']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'left side of field']]]
#
# Situation 10
# Situation graph: [['object', 'large rock'], ['location', 'bottom of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'move to object'], ['object', 'large rock'], ['location', 'bottom of rock pile']], [['actor', 'human'], ['action', 'stand still in location'], ['location', 'bottom of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock']]]
#
# Situation 11
# Situation graph: [['object', 'large rock'], ['object', 'small rock'], ['actor', 'robot'], ['actor', 'human'], ['location', 'left side of field'], ['location', 'right side of field']]
# Human action graphs: [[['actor', 'human'], ['object', 'small rock'], ['action', 'pick up object in location']], [['location', 'left side of field'], ['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock']], [['action', 'drop object in location'], ['actor', 'robot'], ['location', 'left side of field']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock']], [['actor', 'robot'], ['action', 'drop object in location'], ['location', 'right side of field'], ['object', 'large rock']]]
#
# Situation 12
# Situation graph: [['object', 'large rock'], ['location', 'bottom of rock pile'], ['actor', 'robot'], ['actor', 'human']]
# Human action graphs: [[['actor', 'human'], ['action', 'stand still in location'], ['location', 'bottom of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to object'], ['object', 'large rock']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'large rock'], ['location', 'right side of field']]]
#
# Participant p07
# Situation 00
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']]]
#
# Situation 01
# Situation graph: [['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
#
# Situation 02
# Situation graph: [['location', 'top of rock pile'], ['object', 'small rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']]]
#
# Situation 03
# Situation graph: [['location', 'top of rock pile'], ['object', 'small rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']]]
# Robot action graphs: []
#
# Situation 04
# Situation graph: [['actor', 'human'], ['object', 'small rock']]
# Human action graphs: []
# Robot action graphs: []
#
# Situation 05
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile']]]
#
# Situation 06
# Situation graph: [['actor', 'robot'], ['object', 'large rock']]
# Human action graphs: []
# Robot action graphs: []
#
# Situation 07
# Situation graph: [['actor', 'robot'], ['object', 'small rock']]
# Human action graphs: []
# Robot action graphs: []
#
# Situation 08
# Situation graph: [['location', 'bottom of rock pile'], ['object', 'small rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'bottom of rock pile']]]
# Robot action graphs: []
#
# Situation 09
# Situation graph: [['location', 'bottom of rock pile'], ['object', 'large rock']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'bottom of rock pile']]]
#
# Situation 10
# Situation graph: [['location', 'bottom of rock pile'], ['object', 'small rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'bottom of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'bottom of rock pile']]]
#
# Situation 11
# Situation graph: [['actor', 'robot'], ['object', 'large rock']]
# Human action graphs: []
# Robot action graphs: []
#
# Situation 12
# Situation graph: [['object', 'small rock'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']]]
# Robot action graphs: []
#
# Situation 13
# Situation graph: [['object', 'large rock'], ['location', 'on top of object'], ['object', 'small rock']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'bottom of rock pile']]]
#
# Situation 14
# Situation graph: [['actor', 'human'], ['object', 'small rock']]
# Human action graphs: []
# Robot action graphs: []
#
# Situation 15
# Situation graph: [['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'bottom of rock pile']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'move back and forth in location'], ['location', 'bottom of rock pile']]]
#
# Situation 16
# Situation graph: [['actor', 'human'], ['object', 'small rock']]
# Human action graphs: []
# Robot action graphs: []
#
# Situation 17
# Situation graph: [['actor', 'human'], ['action', 'move to object'], ['object', 'large rock']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'human']]]
#
# Situation 18
# Situation graph: [['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
# Robot action graphs: []
#
# Situation 19
# Situation graph: [['actor', 'robot'], ['object', 'small rock']]
# Human action graphs: []
# Robot action graphs: []
#
# Situation 20
# Situation graph: [['actor', 'human'], ['action', 'move to object'], ['object', 'large rock']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'stand still in location'], ['location', 'on top of location'], ['location', 'right side of field']]]
#
# Situation 21
# Situation graph: [['location', 'bottom of rock pile'], ['object', 'large rock']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'bottom of rock pile']]]
#
# Situation 22
# Situation graph: [['actor', 'human'], ['action', 'move to object'], ['object', 'large rock']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'human']]]
#
# Participant p09
# Situation 00
# Situation graph: [['object', 'large rock'], ['location', 'top of rock pile'], ['object', 'large rock'], ['location', 'above rock pile'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock']]]
#
# Situation 01
# Situation graph: [['object', 'small rock'], ['location', 'top of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'stand still in location']]]
#
# Situation 02
# Situation graph: [['object', 'large rock'], ['location', 'top of rock pile'], ['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'move to location'], ['object', 'large rock'], ['location', 'left side of field']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to location'], ['object', 'large rock'], ['location', 'left side of field']], [['actor', 'robot'], ['action', 'break object in location']]]
#
# Situation 03
# Situation graph: [['object', 'small rock'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to actor'], ['actor', 'human']]]
#
# Situation 04
# Situation graph: [['object', 'large rock'], ['location', 'top of rock pile'], ['object', 'large rock'], ['location', 'left side of rock pile'], ['object', 'small rock'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'move back and forth in location'], ['location', 'right side of field']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'drop object in location'], ['object', 'large rock'], ['location', 'right side of field']]]
#
# Situation 05
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'move to object'], ['object', 'large rock'], ['location', 'left side of rock pile']], [['actor', 'human'], ['action', 'stand still in location']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
#
# Situation 06
# ...
#
# Situation 18
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock'], ['location', 'top of rock pile'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'stand still in location'], ['location', 'top of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']]]
#
# Situation 19
# Situation graph: [['object', 'large rock'], ['location', 'top of rock pile']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['location', 'top of rock pile'], ['object', 'large rock']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'large rock'], ['location', 'left side of field'], ['location', 'above rock pile']]]
#
# Situation 20
# Situation graph: [['object', 'small rock'], ['location', 'top of rock pile']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'right side of field'], ['location', 'above rock pile']]]
#
# Situation 21
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'stand still in location'], ['location', 'left side of rock pile']]]
# Robot action graphs: []
#
# Situation 22
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'stand still in location'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
#
# Situation 23
# Situation graph: [['location', 'top of rock pile'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']]]
#
# Situation 24
# Situation graph: [['object', 'small rock'], ['location', 'right side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['location', 'right side of rock pile'], ['object', 'small rock']], [['actor', 'human'], ['action', 'move to location'], ['location', 'left side of field']], [['actor', 'human'], ['action', 'move to location'], ['location', 'right side of field']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'right side of field']]]
# Robot action graphs: []
#
# Situation 25
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
#
# Situation 26
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'stand still in location'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['object', 'large rock'], ['location', 'left side of rock pile'], ['action', 'pick up object in location']], [['actor', 'robot'], ['action', 'drop object in location'], ['location', 'right side of field'], ['location', 'above rock pile'], ['object', 'large rock']]]
#
# Situation 27
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'stand still in location'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['object', 'large rock'], ['location', 'left side of rock pile'], ['action', 'pick up object in location']]]
#
# Participant p15
# Situation 00
# Situation graph: [['object', 'large rock'], ['location', 'top of rock pile'], ['location', 'on top of object'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']]]
#
# Situation 01
# Situation graph: [['object', 'large rock'], ['location', 'on top of object'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim'], ['object', 'small rock'], ['location', 'on top of object'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'stand still in location'], ['location', 'right side of field']]]
#
# Situation 02
# Situation graph: [['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move back and forth in location'], ['location', 'on top of actor'], ['actor', 'human']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']], [['actor', 'robot'], ['action', 'stand still in location'], ['location', 'right side of field']]]
#
# Situation 03
# Situation graph: [['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
#
# Situation 04
# Situation graph: [['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['location', 'top of rock pile'], ['location', 'bottom of rock pile']]]
# Robot action graphs: []
#
# Situation 05
# Situation graph: [['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
#
# Situation 06
# Situation graph: [['object', 'large rock'], ['object', 'small rock'], ['location', 'top of rock pile'], ['location', 'on top of object'], ['object', 'large rock']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
#
# Situation 07
# Situation graph: [['object', 'small rock'], ['location', 'on top of object'], ['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'on top of object'], ['object', 'large rock']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'right side of field']]]
#
# Situation 08
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'large rock'], ['location', 'right side of field']]]
#
# Situation 09
# Situation graph: [['object', 'small rock'], ['location', 'on top of object'], ['actor', 'victim'], ['location', 'top of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'stand still in location'], ['location', 'left side of field']]]
# Robot action graphs: []
#
# Situation 10
# Situation graph: [['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
#
# Situation 11
# Situation graph: [['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile'], ['location', 'on top of actor'], ['actor', 'victim']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'left side of field']]]
# Robot action graphs: []
#
# Situation 12
# Situation graph: [['actor', 'human'], ['action', 'move back and forth in location'], ['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'move back and forth in location'], ['location', 'above rock pile']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
#
# Situation 13
# Situation graph: [['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'left side of field']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move back and forth in location'], ['location', 'left side of rock pile']]]
#
# Situation 14
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['action', 'move back and forth in location'], ['location', 'on top of object'], ['object', 'large rock']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock']]]
#
# Situation 15
# Situation graph: [['object', 'small rock'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
#
# Situation 16
# Situation graph: [['object', 'small rock'], ['object', 'large rock'], ['location', 'top of rock pile'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'move back and forth in location'], ['location', 'on top of object'], ['object', 'large rock'], ['location', 'top of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'top of rock pile']]]
#
# Situation 17
# Situation graph: [['object', 'small rock'], ['location', 'top of rock pile'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move back and forth in location'], ['location', 'on top of actor'], ['actor', 'human']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']], [['actor', 'robot'], ['action', 'break object in location'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
#
# Situation 18
# Situation graph: [['object', 'small rock'], ['object', 'large rock'], ['location', 'top of rock pile'], ['location', 'left side of rock pile']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'large rock'], ['location', 'left side of field']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'top of rock pile']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'right side of field']]]
#
# Situation 19
# Situation graph: [['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'move to object'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'move to object'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'on top of actor'], ['actor', 'victim']]]
#
# Situation 20
# Situation graph: [['object', 'small rock'], ['object', 'large rock'], ['location', 'top of rock pile'], ['location', 'on top of object'], ['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: []
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'left side of field']], [['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'large rock'], ['location', 'left side of field']]]
#
# Situation 21
# Situation graph: [['object', 'small rock'], ['location', 'left side of rock pile'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']]
# Human action graphs: [[['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'left side of rock pile']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'left side of field']], [['actor', 'human'], ['action', 'pick up object in location'], ['object', 'small rock'], ['location', 'on top of actor'], ['actor', 'victim']], [['actor', 'human'], ['action', 'drop object in location'], ['object', 'small rock'], ['location', 'left side of field']]]
# Robot action graphs: []
#
# Situation 22
# Situation graph: [['object', 'large rock'], ['location', 'left side of rock pile']]
# Human action graphs: [[['actor', 'human'], ['location', 'on top of object'], ['object', 'large rock'], ['location', 'left side of rock pile']]]
# Robot action graphs: [[['actor', 'robot'], ['action', 'pick up object in location'], ['object', 'large rock'], ['location', 'left side of rock pile']], [['actor', 'robot'], ['action', 'drop object in location'], ['object', 'large rock'], ['location', 'right side of field']]]

# %% [markdown]
# ## convert the python dict to RDF/Turtle data

# %%
from typing import List
from collections import defaultdict


def order_types(list_of_type_and_literal: List[List[str]]) -> List[List[str]]:
    """Order the types and literals in a list of lists.

    Args:
        list_of_type_and_literal (List[List[str]]): A list of lists containing the types and literals

    Returns:
        List[List[str]]: A list of lists containing the ordered types and literals

    """
    # Define the order of the types
    order = ["actor", "action", "object", "location"]

    assert all(
        x[0] in order for x in list_of_type_and_literal
    ), f"Unknown type: {list_of_type_and_literal}"

    return sorted(list_of_type_and_literal, key=lambda x: order.index(x[0]))


def type_and_literal_to_turtle(type_: str, literal: str) -> str:
    """Convert a type and literal to a Turtle string.

    Args:
        type_ (str): The type
        literal (str): The literal

    Returns:
        str: The Turtle string

    """
    # literal = f'"{", ".join(literal)}"'
    return f'    colearn:{type_}Type "{literal}" ;'


def is_valid_actions_in_graph(graph: List[List[str]]) -> bool:
    """Check if the actions in the graph are valid.

    Args:
        graph (List[List[str]]): A list of lists containing the graph

    Returns:
        bool: True if the actions are valid, False otherwise

    """
    for action in graph:
        if len(action) > 0:
            return True

    return False


def add_human_or_robot_action_to_turtle(
    list_of_actions: list,
    participant_id: str,
    situation_id: str,
    human_or_robot: str,
) -> List[str]:

    num_actions = len(list_of_actions)
    turtle_content = []

    actor = "Human" if human_or_robot.lower() == "human" else "Robot"
    prefix = "h" if human_or_robot.lower() == "human" else "r"

    turtle_content.append(f"# Define the {actor} actions.")

    for idx_a, action in enumerate(list_of_actions):
        action_id = f"{prefix}{idx_a:02}"
        next_action_id = f"{prefix}{idx_a+1:02}"
        previous_action_id = f"{prefix}{idx_a-1:02}"

        turtle_content.append(
            f"colearn:{participant_id}_{situation_id}_{action_id} a colearn:{actor}Action ;"
        )
        turtle_content.append(
            f'    rdfs:label "Participant {participant_id}, Situation {situation_id}, {actor}-Action {action_id}" ;'
        )
        list_of_type_and_literal = order_types(action)
        for type_, literal in list_of_type_and_literal:
            turtle_content.append(type_and_literal_to_turtle(type_, literal))

        if idx_a == 0 and num_actions > 1:
            turtle_content.append(
                f"    colearn:isActionOf colearn:{participant_id}_{situation_id} ;"
            )
            turtle_content.append(
                f"    colearn:hasNextAction colearn:{participant_id}_{situation_id}_{next_action_id} .\n"
            )
        elif idx_a == 0 and num_actions == 1:
            turtle_content.append(
                f"    colearn:isActionOf colearn:{participant_id}_{situation_id} .\n"
            )
        elif idx_a > 0 and idx_a < num_actions - 1:
            turtle_content.append(
                f"    colearn:isActionOf colearn:{participant_id}_{situation_id} ;"
            )
            turtle_content.append(
                f"    colearn:hasNextAction colearn:{participant_id}_{situation_id}_{next_action_id} ;"
            )
            turtle_content.append(
                f"    colearn:hasPreviousAction colearn:{participant_id}_{situation_id}_{previous_action_id} .\n"
            )
        elif idx_a == num_actions - 1:
            turtle_content.append(
                f"    colearn:isActionOf colearn:{participant_id}_{situation_id} ;"
            )
            turtle_content.append(
                f"    colearn:hasPreviousAction colearn:{participant_id}_{situation_id}_{previous_action_id} .\n"
            )
        else:
            raise ValueError(
                f"Unknown {actor} action for participant {participant_id}, situation {situation_id}, action {action_id}"
            )

    return turtle_content


def create_turtle(participant_id: str, data: List[dict]) -> List[str]:
    """Create a Turtle file from the data.

    Args:
        participant_id (str): The participant ID
        data (List[dict]): A list of dictionaries containing the data

    Returns:
        List[str]: A list of strings containing the Turtle content

    """
    # Define the header and namespaces
    turtle_content = [
        "@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .",
        "@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .",
        "@prefix owl: <http://www.w3.org/2002/07/owl#> .",
        "@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .",
        "@prefix colearn: <http://example.org/colearn#> .",
        "",
        # Define the main participant
        f"# Define a participant",
        f"colearn:{participant_id} a colearn:Participant ;",
        f'    rdfs:label "Participant {participant_id}" .',
        f"",
    ]

    for idx_s, situation in enumerate(data):

        is_valid_situation = False if situation["situation_graph"] is None else True
        is_human_action = is_valid_actions_in_graph(situation["human_action_graph"])
        is_robot_action = is_valid_actions_in_graph(situation["robot_action_graph"])

        if not is_valid_situation:
            continue
        if not is_human_action and not is_robot_action:
            continue

        situation_id = f"s{idx_s:02}"
        turtle_content.append(f"# A new situation {participant_id}_{situation_id} starts")
        turtle_content.append(
            f"colearn:{participant_id} colearn:hasSituation colearn:{participant_id}_{situation_id} .\n"
        )
        turtle_content.append(f"# Define a situation.")
        turtle_content.append(
            f"colearn:{participant_id}_{situation_id} a colearn:Situation ;"
        )
        turtle_content.append(
            f'    rdfs:label "Participant {participant_id}, Situation {situation_id}" ;'
        )
        turtle_content.append(f"    colearn:isSituationOf colearn:{participant_id} ;")

        list_of_type_and_literal = order_types(situation["situation_graph"])
        for type_, literal in list_of_type_and_literal:
            turtle_content.append(type_and_literal_to_turtle(type_, literal))

        if is_human_action and is_robot_action:
            turtle_content.append(
                f"    colearn:hasHumanAction colearn:{participant_id}_{situation_id}_h00 ;"
            )
            turtle_content.append(
                f"    colearn:hasRobotAction colearn:{participant_id}_{situation_id}_r00 .\n"
            )
        elif is_human_action and not is_robot_action:
            turtle_content.append(
                f"    colearn:hasHumanAction colearn:{participant_id}_{situation_id}_h00 .\n"
            )
        elif not is_human_action and is_robot_action:
            turtle_content.append(
                f"    colearn:hasRobotAction colearn:{participant_id}_{situation_id}_r00 .\n"
            )
        else:
            continue

        if is_human_action:
            content_human = add_human_or_robot_action_to_turtle(
                situation["human_action_graph"],
                participant_id,
                situation_id,
                "Human",
            )
            turtle_content.extend(content_human)

        if is_robot_action:
            content_robot = add_human_or_robot_action_to_turtle(
                situation["robot_action_graph"],
                participant_id,
                situation_id,
                "Robot",
            )
            turtle_content.extend(content_robot)

    return turtle_content


def save_turtle_file(filename: str, content: List[str]):
    """Save the Turtle content to a file.

    Args:
        filename (str): The filename
        content (List[str]): The content to be saved

    """
    with open(filename, "w", encoding="utf-8") as f:
        for line in content:
            f.write(line + "\n")
    print(f"Turtle data saved to {filename}.")


for participant_id, list_of_situations in data.items():
    # Generate Turtle content from data
    turtle_content = create_turtle(participant_id, list_of_situations)

    # Save to a Turtle file
    save_turtle_file(f"./data/{participant_id}.ttl", turtle_content)
# Out:
# Turtle data saved to ./data/p01.ttl.
# Turtle data saved to ./data/p03.ttl.
# Turtle data saved to ./data/p04.ttl.
# Turtle data saved to ./data/p05.ttl.
# Turtle data saved to ./data/p06.ttl.
# Turtle data saved to ./data/p07.ttl.
# Turtle data saved to ./data/p09.ttl.
# Turtle data saved to ./data/p13.ttl.
# Turtle data saved to ./data/p14.ttl.
# Turtle data saved to ./data/p15.ttl.
