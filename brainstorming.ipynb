# %%
import pandas as pd
from bs4 import BeautifulSoup
import ast
import json


# Load CSV data
data = pd.read_csv("./user-data/new/all_cp_messages.csv", sep=";")

# Initialize an empty dictionary to store the final output
all_cp_messages = {}

# Iterate through each row in the DataFrame
for index, row in data.iterrows():
    participant = row["Participant"]
    roundnr = row["Roundnr"]

    # Ensure that the participant exists in the result dictionary
    if participant not in all_cp_messages:
        all_cp_messages[participant] = {}

    # Collect all valid entries from the row, starting from the third column
    round_data = [row[col] for col in data.columns[2:] if pd.notna(row[col])]

    # Process each element in round_data and parse it
    parsed_round_data = []
    for element in round_data:
        # Convert the string to a dictionary using ast.literal_eval
        outer_dict = ast.literal_eval(element)

        # Initialize a dictionary to store parsed values from 'html'
        parsed_html = {}

        for key, value in outer_dict.items():

            if key != "html":
                parsed_html[key] = value
            elif key == "html" and value is not None:
                html_content = json.loads(outer_dict["html"])

                # Process 'situation' if present
                if "situation" in html_content:
                    situation_soup = BeautifulSoup(
                        html_content["situation"], "html.parser"
                    )
                    situation_values = [
                        el.get_text(strip=True)
                        for el in situation_soup.find_all(["p", "i"])
                    ]
                    parsed_html["situation"] = situation_values

                # Process 'actionA' if present
                if "actionA" in html_content:
                    actionA_soup = BeautifulSoup(html_content["actionA"], "html.parser")
                    patternboxes_A = actionA_soup.find_all("div", class_="box_cp box_action")

                    actionA_values = []
                    for box in patternboxes_A:
                        pattern_values = [
                            el.get_text(strip=True)
                            for el in box.find_all(["p", "i"])
                        ]
                        if pattern_values:
                            actionA_values.append(pattern_values)

                    parsed_html["actionA"] = actionA_values

                # Process 'actionB' if present
                if "actionB" in html_content:
                    actionB_soup = BeautifulSoup(html_content["actionB"], "html.parser")
                    patternboxes_B = actionB_soup.find_all("div", class_="box_cp box_action")

                    actionB_values = []
                    for box in patternboxes_B:
                        pattern_values = [
                            el.get_text(strip=True)
                            for el in box.find_all(["p", "i"])
                        ]
                        if pattern_values:
                            actionB_values.append(pattern_values)

                    parsed_html["actionB"] = actionB_values

                # Process 'postsitu' if present
                if "postsitu" in html_content:
                    postsitu_soup = BeautifulSoup(
                        html_content["postsitu"], "html.parser"
                    )
                    postsitu_values = [
                        el.get_text(strip=True)
                        for el in postsitu_soup.find_all(["p", "i"])
                    ]
                    parsed_html["postsitu"] = postsitu_values

                parsed_round_data.append(parsed_html)

    # Store the parsed round data under the specific participant and round number
    all_cp_messages[participant][roundnr] = parsed_round_data

# Now 'all_cp_messages' contains the parsed data for each participant and round
all_cp_messages
# Out:
# {4069: {1: [],
#   2: [],
#   3: [{'cp_new': 'Label',
#     'situation': ['Human'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field'],
#      ['Move to', 'Object', 'Small rock']],
#     'actionB': [['Break', 'object', 'in', 'location'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock']],
#     'postsitu': []},
#    {'cp_edit': 'Label',
#     'situation': [],
#     'actionA': [['Human',
#       'Stand still in',
#       'location',
#       'Left',
#       'side of field']],
#     'actionB': [['Break', 'object', 'in', 'location', 'Brown rock']],
#     'postsitu': []}],
#   4: [{'cp_delete': 'Label',
#     'situation': [],
#     'actionA': [['Human',
#       'Stand still in',
#       'location',
#       'Left',
#       'side of field']],
#     'actionB': [['Break', 'object', 'in', 'location', 'Brown rock']],
#     'postsitu': []},
#    {'cp_new': 'Label',
#     'situation': [],
#     'actionA': [['Human',
#       'Stand still in',
#       'location',
#       'Left',
#       'side of field']],
#     'actionB': [['Break', 'object', 'in', 'location', 'Brown rock']],
#     'postsitu': []},
#    {'cp_edit': 'Label',
#     'situation': [],
#     'actionA': [],
#     'actionB': [],
#     'postsitu': []},
#    {'cp_edit': 'Label',
#     'situation': [],
#     'actionA': [['Left', 'side of rock pile', 'Stand still in', 'location']],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'Label',
#     'situation': [],
#     'actionA': [['Left', 'side of rock pile', 'Stand still in', 'location']],
#     'actionB': [['Large rock',
#       'Drop',
#       'object',
#       'in',
#       'location',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []}],
#   5: [{'cp_edit': 'Label',
#     'situation': [],
#     'actionA': [['Stand still in', 'location', 'Top of rock pile'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile',
#       'Above rock pile',
#       'Bottom of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'actionB': [['Break', 'object', 'in', 'location', 'Brown rock'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile',
#       'Above rock pile',
#       'Bottom of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'On top of',
#       'Object']],
#     'postsitu': []},
#    {'cp_edit': 'Label',
#     'situation': [],
#     'actionA': [['Stand still in', 'location', 'Top of rock pile'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile',
#       'Above rock pile',
#       'Bottom of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'actionB': [['Break', 'object', 'in', 'location', 'Brown rock'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile',
#       'Above rock pile',
#       'Bottom of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []}],
#   6: [],
#   7: [],
#   8: []},
#  4070: {1: [{'cp_new': 'Large rock removal',
#     'situation': ['Large rock', 'Above rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'Large rock removal',
#     'situation': ['Above rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': []}],
#   2: [{'cp_edit': 'Large rock removal',
#     'situation': ['Above rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Above rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'Large rock removal',
#     'situation': ['Above rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Above rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': []},
#    {'cp_new': 'large rock removal 2',
#     'situation': ['Robot', 'Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Above rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []}],
#   3: [{'cp_edit': 'large rock removal 2',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Above rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []}],
#   4: [{'cp_new': 'Label',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location'], ['Above rock pile']],
#     'actionB': [['Pick up', 'object', 'in', 'location'],
#      ['Large rock'],
#      ['Top of rock pile']],
#     'postsitu': []}],
#   5: [{'cp_new': 'do not remove heavy rocks abouve the victim',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Victim'],
#     'actionA': [],
#     'actionB': [['Stand still in', 'location'], ['Above rock pile']],
#     'postsitu': []}],
#   6: [],
#   7: [],
#   8: []},
#  4073: {1: [{'cp_new': 'Small rocks on top',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile',
#       'Small rock']],
#     'actionB': [['Stand still in', 'location', 'Right', 'side of field']],
#     'postsitu': []},
#    {'cp_new': 'Large rocks on top',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Human',
#       'Stand still in',
#       'location',
#       'Left',
#       'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': []}],
#   2: [{'cp_edit': 'Small rocks on top',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile',
#       'Small rock'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'actionB': [['Stand still in', 'location', 'Right', 'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'Large rocks on top',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Human',
#       'Stand still in',
#       'location',
#       'Left',
#       'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': []}],
#   3: [],
#   4: [{'cp_new': 'Large rock on top V2',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Right',
#       'side of field',
#       'Large rock']],
#     'postsitu': []},
#    {'cp_new': 'small rocks on top V2',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Left',
#       'side of rock pile',
#       'Small rock']],
#     'actionB': [['Stand still in', 'location', 'Right', 'side of field']],
#     'postsitu': []}],
#   5: [{'cp_new': 'large rocks on top V4',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'small rocks on top V2',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Left',
#       'side of rock pile',
#       'Small rock']],
#     'actionB': [['Stand still in', 'location', 'Right', 'side of field']],
#     'postsitu': []}],
#   6: [{'cp_new': 'brown rock and small rocks on top',
#     'situation': ['Brown rock', 'Small rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'brown rock and small rocks on top',
#     'situation': ['Brown rock', 'Small rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile'],
#      ['Move back and forth in', 'location', 'Right', 'side of field']],
#     'postsitu': []},
#    {'cp_new': 'brown rock on top',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile'],
#      ['Move back and forth in', 'location', 'Right', 'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'brown rock on top',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Brown rock',
#       'Top of rock pile',
#       'Pick up',
#       'object',
#       'in',
#       'location'],
#      ['Right',
#       'side of field',
#       'Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock']],
#     'postsitu': []},
#    {'cp_edit': 'large rocks on top V4',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': []}],
#   7: [{'cp_edit': 'brown rock on top',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Brown rock',
#       'Top of rock pile',
#       'Pick up',
#       'object',
#       'in',
#       'location'],
#      ['Right',
#       'side of field',
#       'Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock']],
#     'postsitu': []}],
#   8: [{'cp_edit': 'brown rock on top',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Top of rock pile',
#       'Brown rock',
#       'Pick up',
#       'object',
#       'in',
#       'location'],
#      ['Right',
#       'side of field',
#       'Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock']],
#     'postsitu': []},
#    {'cp_new': 'large rocks on top V5',
#     'situation': ['Top of rock pile', 'Large rock', 'Brown rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'large rocks on top V5',
#     'situation': ['Top of rock pile',
#      'Large rock',
#      'Brown rock',
#      'Small rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'large rocks on top V5',
#     'situation': ['Top of rock pile',
#      'Large rock',
#      'Brown rock',
#      'Small rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Large rock',
#       'Top of rock pile',
#       'Pick up',
#       'object',
#       'in',
#       'location'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': []}]},
#  4081: {1: [{'cp_new': 'top large',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'top large',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Right', 'side of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'top large',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Right', 'side of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'top large',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []}],
#   2: [],
#   3: [],
#   4: [],
#   5: [],
#   6: [{'cp_new': 'top brown',
#     'situation': ['Top of rock pile', 'Brown rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Right',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'top brown',
#     'situation': ['Top of rock pile', 'Brown rock'],
#     'actionA': [['Stand still in', 'location', 'Above rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Right',
#       'side of field']],
#     'postsitu': []},
#    {'cp_new': 'top brown test',
#     'situation': ['Brown rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Above rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'On top of',
#       'Object',
#       'Large rock'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Right',
#       'side of field']],
#     'postsitu': []}],
#   7: [{'cp_edit': 'top brown test',
#     'situation': ['Brown rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'On top of',
#       'Object',
#       'Large rock'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Right',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'top brown test',
#     'situation': ['Brown rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'On top of',
#       'Object',
#       'Large rock'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Right',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'top brown test',
#     'situation': ['Brown rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'On top of',
#       'Object',
#       'Large rock'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'top brown test',
#     'situation': ['Brown rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Stand still in', 'location', 'Above rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'top brown test',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'top brown test',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'top brown test',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Top of rock pile']],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'top brown',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of field']],
#     'postsitu': []}],
#   8: [{'cp_edit': 'top brown',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'large below',
#     'situation': ['Large rock', 'On top of', 'Object', 'Small rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'On top of',
#       'Object',
#       'Small rock'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []}]},
#  4082: {1: [{'cp_new': 'Remove big rock',
#     'situation': ['Right', 'side of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'Remove large rock top',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': []}],
#   2: [{'cp_new': 'Large rock on human',
#     'situation': ['Bottom of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Bottom of rock pile',
#       'Large rock']],
#     'postsitu': []}],
#   3: [],
#   4: [],
#   5: [{'cp_new': 'Brown rock',
#     'situation': ['On top of', 'Object', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'On top of',
#       'Object',
#       'Large rock']],
#     'postsitu': []},
#    {'cp_new': 'Brown rock',
#     'situation': ['Right', 'side of rock pile', 'Brown rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': []}],
#   6: [{'cp_edit': 'Remove brown rock at top',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'postsitu': []}],
#   7: [{'cp_new': 'Brown rock and small rocks',
#     'situation': ['Top of rock pile', 'Brown rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'Brown rock and small rocks',
#     'situation': ['Top of rock pile', 'Brown rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Above rock pile']],
#     'postsitu': []},
#    {'cp_new': 'Label',
#     'situation': [],
#     'actionA': [],
#     'actionB': [],
#     'postsitu': []},
#    {'cp_edit': 'Brown rock and small rocks',
#     'situation': ['Top of rock pile', 'Brown rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'On top of',
#       'Object']],
#     'postsitu': []},
#    {'cp_edit': 'Label',
#     'situation': ['Left', 'side of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'Brown rock',
#     'situation': ['Right', 'side of rock pile', 'Brown rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'postsitu': []}],
#   8: [{'cp_new': 'Remove multiple large rocks',
#     'situation': ['Top of rock pile', 'Brown rock', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': []}]},
#  4083: {1: [],
#   2: [{'cp_new': 'Decent',
#     'situation': ['Top of rock pile',
#      'Large rock',
#      'Bottom of rock pile',
#      'Large rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Right',
#       'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Left',
#       'side of field',
#       'Large rock']],
#     'postsitu': []}],
#   3: [{'cp_new': 'Good',
#     'situation': ['Top of rock pile',
#      'Large rock',
#      'Bottom of rock pile',
#      'Large rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Right',
#       'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Left',
#       'side of field',
#       'Large rock']],
#     'postsitu': []}],
#   4: [{'cp_edit': 'Good',
#     'situation': ['Top of rock pile',
#      'Large rock',
#      'Bottom of rock pile',
#      'Large rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Right',
#       'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Left',
#       'side of field',
#       'Large rock']],
#     'postsitu': []},
#    {'cp_new': 'Do soemthing',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []},
#    {'cp_new': 'Only small rocks',
#     'situation': ['Small rock', 'Top of rock pile'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'actionB': [['Small rock',
#       'Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'postsitu': []},
#    {'cp_new': 'Do something when only big rock',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []}],
#   5: [{'cp_new': 'Brown rock on top',
#     'situation': ['Top of rock pile', 'Brown rock'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Bottom of rock pile']],
#     'postsitu': []}],
#   6: [{'cp_new': 'Brown rock on top + large rock on bottom',
#     'situation': ['Brown rock',
#      'Top of rock pile',
#      'Bottom of rock pile',
#      'Large rock'],
#     'actionA': [],
#     'actionB': [],
#     'postsitu': []}],
#   7: [{'cp_edit': 'Brown rock on top',
#     'situation': ['Top of rock pile', 'Brown rock'],
#     'actionA': [],
#     'actionB': [['Large rock',
#       'Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'Brown rock on top',
#     'situation': ['Top of rock pile',
#      'Brown rock',
#      'Bottom of rock pile',
#      'Large rock'],
#     'actionA': [],
#     'actionB': [['Large rock',
#       'Pick up',
#       'object',
#       'in',
#       'location',
#       'Bottom of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []}],
#   8: [{'cp_edit': 'Brown rock on top',
#     'situation': ['Top of rock pile',
#      'Brown rock',
#      'Bottom of rock pile',
#      'Large rock'],
#     'actionA': [],
#     'actionB': [['Large rock',
#       'Pick up',
#       'object',
#       'in',
#       'location',
#       'Bottom of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []}]},
#  4085: {1: [{'cp_new': 'large rock robot ',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []}],
#   2: [],
#   3: [{'cp_new': 'Robot large then small on top',
#     'situation': ['Bottom of rock pile', 'Small rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field'],
#      ['Pick up', 'object', 'in', 'location', 'Small rock', 'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Right',
#       'side of field']],
#     'postsitu': []}],
#   4: [],
#   5: [{'cp_edit': 'large rock robot ',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []}],
#   6: [{'cp_new': 'large rocks gone',
#     'situation': ['Large rock',
#      'Top of rock pile',
#      'Large rock',
#      'Bottom of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Bottom of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': []}],
#   7: [{'cp_edit': 'large rocks gone',
#     'situation': ['Large rock',
#      'Top of rock pile',
#      'Large rock',
#      'Bottom of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Bottom of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': []}],
#   8: []},
#  4086: {1: [{'cp_new': 'Large rock on top of pile',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Top of rock pile']],
#     'actionB': [['Move to', 'Location', 'Top of rock pile'],
#      ['Pick up', 'object', 'in', 'location', 'Large rock', 'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []},
#    {'cp_new': 'Breaking large rocks',
#     'situation': ['Large rock'],
#     'actionA': [['Stand still in',
#       'location',
#       'On top of',
#       'Object',
#       'Large rock']],
#     'actionB': [['Move to', 'Object', 'Large rock'],
#      ['Break', 'object', 'in', 'location', 'Large rock']],
#     'postsitu': []},
#    {'cp_edit': 'Large rock on top of pile',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Top of rock pile']],
#     'actionB': [['Move to', 'Location', 'Top of rock pile'],
#      ['Pick up', 'object', 'in', 'location', 'Large rock', 'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'Breaking large rocks',
#     'situation': ['Large rock'],
#     'actionA': [['Stand still in',
#       'location',
#       'On top of',
#       'Object',
#       'Large rock']],
#     'actionB': [['Move to', 'Object', 'Large rock'],
#      ['Break', 'object', 'in', 'location', 'Large rock']],
#     'postsitu': []},
#    {'cp_edit': 'Breaking large rocks',
#     'situation': ['Large rock'],
#     'actionA': [['Move to', 'Object', 'Large rock']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'On top of',
#       'Actor',
#       'Human']],
#     'postsitu': []},
#    {'cp_edit': 'Large rock on top of pile',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Top of rock pile'],
#      ['Move to', 'Object', 'Large rock']],
#     'actionB': [['Move to', 'Location', 'Top of rock pile'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'On top of',
#       'Actor',
#       'Human'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []}],
#   2: [{'cp_edit': 'Breaking large rocks',
#     'situation': ['Large rock'],
#     'actionA': [['Move to', 'Object', 'Large rock']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'On top of',
#       'Actor',
#       'Human']],
#     'postsitu': []},
#    {'cp_edit': 'Large rock on top of pile',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Top of rock pile'],
#      ['Move to', 'Object', 'Large rock']],
#     'actionB': [['Move to', 'Location', 'Top of rock pile'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'On top of',
#       'Actor',
#       'Human'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'Breaking large rocks',
#     'situation': ['Large rock'],
#     'actionA': [['Move to', 'Object', 'Large rock']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'On top of',
#       'Actor',
#       'Human']],
#     'postsitu': []},
#    {'cp_new': 'Large rock in top of pile',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Human'],
#     'actionA': [['Stand still in', 'location', 'Bottom of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []}],
#   3: [{'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Human'],
#     'actionA': [['Stand still in', 'location', 'Bottom of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Human'],
#     'actionA': [['Stand still in', 'location', 'Bottom of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Human'],
#     'actionA': [['Stand still in', 'location', 'Bottom of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'Label',
#     'situation': [],
#     'actionA': [],
#     'actionB': [],
#     'postsitu': []},
#    {'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Human'],
#     'actionA': [['Move to', 'Location', 'Bottom of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Human'],
#     'actionA': [['Move to', 'Location', 'Bottom of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Move to', 'Location', 'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Move to', 'Location', 'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Move to', 'Location', 'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []}],
#   4: [{'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Move to', 'Location', 'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Move to', 'Location', 'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []}],
#   5: [{'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Move to', 'Location', 'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'Label',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Victim'],
#     'actionA': [['Move to', 'Actor', 'Victim']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Bottom of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'Label',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Victim'],
#     'actionA': [['Move to', 'Actor', 'Victim']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []},
#    {'cp_new': 'Rock on the left side of the victim',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Victim'],
#     'actionA': [['Move to', 'Actor', 'Victim'],
#      ['Move to', 'Location', 'Left', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []},
#    {'cp_new': 'Rock on the right side of the victim',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Victim'],
#     'actionA': [['Move to', 'Actor', 'Victim'],
#      ['Move to', 'Location', 'Right', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile'],
#      ['Move to', 'Location', 'Right', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': []}],
#   6: [{'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Move to', 'Location', 'Top of rock pile'],
#      ['Stand still in', 'location', 'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'Rock on the right side of the victim',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Victim'],
#     'actionA': [['Move to', 'Actor', 'Victim'],
#      ['Move to', 'Location', 'Right', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile'],
#      ['Move to', 'Location', 'Right', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'Rock on the left side of the victim',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Victim'],
#     'actionA': [['Move to', 'Actor', 'Victim'],
#      ['Move to', 'Location', 'Left', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Victim'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'Rock on the right side of the victim',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Victim'],
#     'actionA': [['Move to', 'Actor', 'Victim'],
#      ['Move to', 'Location', 'Right', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Victim'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile'],
#      ['Move to', 'Location', 'Right', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'Rock on the left side of the victim',
#     'situation': ['Large rock', 'Left', 'side of field'],
#     'actionA': [['Move to', 'Actor', 'Victim'],
#      ['Move to', 'Location', 'Left', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Victim'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'Rock on the right side of the victim',
#     'situation': ['Large rock', 'Right', 'side of rock pile'],
#     'actionA': [['Move to', 'Actor', 'Victim'],
#      ['Move to', 'Location', 'Right', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Victim'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile'],
#      ['Move to', 'Location', 'Right', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': []},
#    {'cp_edit': 'Rock on the right side of the victim',
#     'situation': ['Large rock', 'Right', 'side of rock pile'],
#     'actionA': [['Move to', 'Actor', 'Victim'],
#      ['Move to', 'Location', 'Right', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Victim'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile'],
#      ['Move to', 'Location', 'Right', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': []},
#    {'cp_new': 'Brown rock in pile',
#     'situation': ['Brown rock', 'On top of', 'Actor', 'Victim'],
# ...
#       'Left',
#       'side of field',
#       'Brown rock']],
#     'postsitu': []},
#    {'cp_edit': 'Large rock',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_new': '3',
#     'situation': ['Robot'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': '3',
#     'situation': ['Robot'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': '3',
#     'situation': ['Robot'],
#     'actionA': [['Move to', 'Object', 'Large rock']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Bottom of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Left',
#       'side of rock pile',
#       'Large rock']],
#     'postsitu': []},
#    {'cp_new': 'Move',
#     'situation': ['Large rock', 'Robot', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Large rock', 'Bottom of rock pile']],
#     'postsitu': []}],
#   6: [{'cp_edit': 'brown rock',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'actionB': [['Move to', 'Object', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'brown rock',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'actionB': [['Move to', 'Object', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'brown rock',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'actionB': [['Move to', 'Object', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'Move',
#     'situation': [],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Human']],
#     'postsitu': []},
#    {'cp_edit': 'Move',
#     'situation': [],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Human']],
#     'postsitu': []}],
#   7: [{'cp_edit': 'Move',
#     'situation': [],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Human']],
#     'postsitu': []},
#    {'cp_edit': 'brown rock',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'actionB': [['Move to', 'Object', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'brown rock',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'actionB': [['Move to', 'Object', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'brown rock',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'actionB': [['Move to', 'Object', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'Large rock',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'brown rock',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'brown rock',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'Move',
#     'situation': [],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Human']],
#     'postsitu': []},
#    {'cp_edit': 'brown rock',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'Label',
#     'situation': [],
#     'actionA': [],
#     'actionB': [],
#     'postsitu': []},
#    {'cp_edit': 'Label',
#     'situation': [],
#     'actionA': [],
#     'actionB': [],
#     'postsitu': []},
#    {'cp_edit': 'Label',
#     'situation': [],
#     'actionA': [],
#     'actionB': [],
#     'postsitu': []}],
#   8: [{'cp_edit': 'brown rock',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'brown rock',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'brown rock',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'brown rock',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'brown rock2',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'move',
#     'situation': ['Robot', 'Brown rock'],
#     'actionA': [],
#     'actionB': [['Move to', 'Actor', 'Human']],
#     'postsitu': []}]},
#  4098: {1: [{'cp_new': 'Handle large rocks before smash',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Object', 'Small rock'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'Wait for human before break',
#     'situation': ['Large rock', 'Right', 'side of rock pile'],
#     'actionA': [['Move to', 'Location', 'Right', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': []}],
#   2: [],
#   3: [{'cp_new': 'Move small rocks off large rocks',
#     'situation': ['Small rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'On top of',
#       'Object',
#       'Large rock']],
#     'postsitu': []}],
#   4: [{'cp_new': 'Unstack large rocks',
#     'situation': ['Large rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Large rock'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'On top of',
#       'Object',
#       'Large rock',
#       'Large rock']],
#     'postsitu': []},
#    {'cp_edit': 'Unstack large rocks',
#     'situation': ['Large rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Large rock'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'On top of',
#       'Object',
#       'Large rock',
#       'Large rock'],
#      ['Drop', 'object', 'in', 'location', 'Left', 'side of field']],
#     'postsitu': []}],
#   5: [{'cp_new': 'Break Brown?',
#     'situation': ['Brown rock', 'Right', 'side of field'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Right',
#       'side of field']],
#     'postsitu': []}],
#   6: [{'cp_new': 'Prevent brown guillotine',
#     'situation': ['Brown rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'On top of',
#       'Object',
#       'Large rock']],
#     'postsitu': []}],
#   7: [],
#   8: []},
#  4099: {1: [{'cp_new': 'BreakBigTop',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': []}],
#   2: [{'cp_new': 'PickBigTop',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'PickUpMultipleSmall',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Pick up', 'object', 'in', 'location', 'Small rock', 'Top of rock pile'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'postsitu': []}],
#   3: [{'cp_new': 'ClearOutBigRocksOverBrown',
#     'situation': [],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'On top of',
#       'Object',
#       'Brown rock']],
#     'postsitu': []}],
#   4: [],
#   5: [{'cp_new': 'RemoveBigLeftSide',
#     'situation': ['Left', 'side of rock pile', 'Brown rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'RemoveBigRight',
#     'situation': ['Right', 'side of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'ComeToMe',
#     'situation': [],
#     'actionA': [['Move back and forth in', 'location']],
#     'actionB': [['Break', 'object', 'in', 'location', 'Large rock']],
#     'postsitu': []}],
#   6: [{'cp_new': 'PickTop',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'BreakBottom',
#     'situation': ['Bottom of rock pile',
#      'Large rock',
#      'Top of rock pile',
#      'Large rock',
#      'Top of rock pile',
#      'Small rock'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Bottom of rock pile']],
#     'postsitu': []},
#    {'cp_new': 'PickUpSmall',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'postsitu': []}],
#   7: [{'cp_new': 'PickUpLarge',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile',
#       'Large rock']],
#     'postsitu': []}],
#   8: [{'cp_new': 'GuidedPickUp',
#     'situation': ['Top of rock pile', 'Brown rock'],
#     'actionA': [['Stand still in',
#       'location',
#       'On top of',
#       'Object',
#       'Large rock']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': []},
#    {'cp_edit': 'GuidedPickUp',
#     'situation': ['Top of rock pile', 'Brown rock'],
#     'actionA': [['Stand still in',
#       'location',
#       'On top of',
#       'Object',
#       'Large rock']],
#     'actionB': [['Pick up', 'object', 'in', 'location', 'Large rock']],
#     'postsitu': []}]}}

# %%
import pandas as pd
import ast

# Load the CSV file
data = pd.read_csv('./user-data/new/cp_execution.csv', sep=';')

# Initialize an empty dictionary to store the final result
cp_execution = {}

# Iterate through each row in the DataFrame
for index, row in data.iterrows():
    participant = row['Participant']
    roundnr = row['Round']

    # Ensure that the participant exists in the result dictionary
    if participant not in cp_execution:
        cp_execution[participant] = {}

    # Collect all valid entries from the row, starting from the third column
    round_data = []
    for col in data.columns[2:]:
        element = row[col]
        if pd.notna(element):
            try:
                # Parse the element as a list
                parsed_element = ast.literal_eval(element)
                round_data.append(parsed_element)
            except (ValueError, SyntaxError):
                # Handle parsing errors gracefully
                round_data.append(element)

    # Store the round data for the specific participant and round
    cp_execution[participant][roundnr] = round_data

# Now 'result' contains the desired dictionary structure
cp_execution
# Out:
# {4069: {1: [[False, 3020]],
#   2: [[False, 3020]],
#   3: [['False', 2239], ['Label', 117]],
#   4: [[False, 3020]],
#   5: [[False, 1917]],
#   6: [[False, 1909]],
#   7: [[False, 2411]],
#   8: [[False, 2445]]},
#  4070: {1: [[False, 3020]],
#   2: [[False, 3020]],
#   3: [[False, 3020]],
#   4: [[False, 2023]],
#   5: [[False, 1559]],
#   6: [[False, 3020]],
#   7: [[False, 2249]],
#   8: [[False, 1660]]},
#  4073: {1: [[False, 3020]],
#   2: [['False', 2], ['Small rocks on top', 3018]],
#   3: [['False', 4], ['Large rocks on top', 546], ['Small rocks on top', 2470]],
#   4: [['False', 2736], ['Large rock on top V2', 284]],
#   5: [['False', 2962], ['small rocks on top V2', 58]],
#   6: [['False', 3],
#    ['small rocks on top V2', 744],
#    ['brown rock and small rocks on top', 2273]],
#   7: [['False', 973], ['brown rock on top', 2047]],
#   8: [['False', 1081],
#    ['brown rock on top', 282],
#    ['large rocks on top V4', 718],
#    ['large rocks on top V5', 896]]},
#  4081: {1: [['False', 1682], ['top large', 1338]],
#   2: [['False', 429], ['top large', 861]],
#   3: [['False', 171], ['top large', 736]],
#   4: [['False', 70], ['top large', 1073]],
#   5: [['False', 612], ['top large', 330]],
#   6: [['False', 282], ['top brown', 1917], ['top brown test', 821]],
#   7: [['False', 2], ['top brown test', 3018]],
#   8: [['False', 363], ['top brown', 2114], ['large below', 543]]},
#  4082: {1: [['False', 2486], ['Remove big rock', 534]],
#   2: [['False', 677],
#    ['Remove large rock top', 1388],
#    ['Remove big rock', 537]],
#   3: [['False', 875],
#    ['Remove large rock top', 1235],
#    ['Remove big rock', 161]],
#   4: [['False', 1168],
#    ['Remove big rock', 420],
#    ['Remove large rock top', 788]],
#   5: [['False', 3],
#    ['remove small rocks at top', 331],
#    ['Remove brown rock at top', 2686]],
#   6: [['False', 2], ['Remove brown rock at top', 3018]],
#   7: [['False', 4],
#    ['Brown rock', 2779],
#    ['Remove large rock top', 1],
#    ['Large rock on human', 66]],
#   8: [['False', 101],
#    ['Brown rock and small rocks', 2581],
#    ['Remove big rock', 286],
#    ['Remove large rock top', 52]]},
#  4083: {1: [[False, 3020]],
#   2: [[False, 2650]],
#   3: [['False', 443], ['Decent', 932]],
#   4: [['False', 2], ['Good', 2875]],
#   5: [['False', 1864], ['Only small rocks', 1052], ['Good', 104]],
#   6: [['False', 2], ['Brown rock on top', 3018]],
#   7: [['False', 422],
#    ['Do something when only big rock', 2],
#    ['Brown rock on top', 2596]],
#   8: [['False', 708],
#    ['Only small rocks', 371],
#    ['Brown rock on top', 953],
#    ['Do something when only big rock', 225]]},
#  4085: {1: [[False, 3020]],
#   2: [['False', 292], ['large rock robot ', 1037]],
#   3: [['False', 433], ['large rock robot ', 948]],
#   4: [['False', 3],
#    ['large rock robot ', 305],
#    ['Robot large then small on top', 2712]],
#   5: [[False, 2597]],
#   6: [['False', 506], ['large rock robot ', 2514]],
#   7: [['False', 1858], ['large rock robot ', 25]],
#   8: [[False, 3020]]},
#  4086: {1: [['False', 1239],
#    ['Large rock on top of pile', 913],
#    ['Breaking large rocks', 868]],
#   2: [['False', 3],
#    ['Breaking large rocks', 2753],
#    ['Large rock on top of pile', 264]],
#   3: [['False', 2], ['Large rock on top of pile', 3018]],
#   4: [['False', 2], ['Large rock in top of pile', 2095]],
#   5: [['False', 421], ['Large rock in top of pile', 250], ['Label', 2347]],
#   6: [['False', 2], ['Rock on the left side of the victim', 3018]],
#   7: [['False', 398],
#    ['Rock on the right side of the victim', 1119],
#    ['Label', 272]],
#   8: [['False', 3],
#    ['Rock on the right side of the victim', 1110],
#    ['Large rock in top of pile', 26]]},
#  4087: {1: [[False, 3020]],
#   2: [['False', 765], ['Move top large rock', 853]],
#   3: [['False', 2], ['Move top small rock', 3018]],
#   4: [['False', 381], ['Move top large rock', 952]],
#   5: [['False', 80], ['Move top large rock', 2940]],
#   6: [['False', 2414], ['Move top large rock', 159]],
#   7: [['False', 1530],
#    ['break right rock', 65],
#    ['Move top large rock', 1425]],
#   8: [['False', 102], ['Move top large rock', 2918]]},
#  4089: {1: [['False', 2837], ['Move', 183]],
#   2: [['False', 2208], ['Break Rock', 812]],
#   3: [['False', 1866], ['Break Rock', 1154]],
#   4: [['False', 1189], ['Break Big Rock', 1572]],
#   5: [[False, 2047]],
#   6: [[False, 2341]],
#   7: [[False, 1835]],
#   8: [[False, 2250]]},
#  4090: {1: [[False, 3020]],
#   2: [['False', 1644], ['Top of the pile', 1376]],
#   3: [['False', 3], ['Top of the pile', 1203], ['Top of pile small', 671]],
#   4: [['False', 4],
#    ['Top of pile small', 310],
#    ['Top of the pile', 792],
#    ['Top of the pile improved', 1914]],
#   5: [['False', 4], ['Top of pile small', 433], ['Left side big rocks', 942]],
#   6: [['False', 3], ['Left side big rocks', 545], ['Top of pile small', 649]],
#   7: [['False', 329],
#    ['Left side big rocks', 296],
#    ['Top of pile small', 905],
#    ['Top of the pile', 261]],
#   8: [['False', 839], ['Left side big rocks', 545], ['Brown rocks', 1636]]},
#  4091: {1: [[False, 3020]],
#   2: [['False', 919], ['1', 2101]],
#   3: [['False', 189], ['1', 2831]],
#   4: [['False', 330], ['1', 1464]],
#   5: [['False', 14], ['3', 3006]],
#   6: [['False', 2], ['3', 3018]],
#   7: [['False', 2], ['1', 3018]],
#   8: [['False', 15], ['Label', 167], ['1', 2820]]},
#  4092: {1: [['False', 2046], ['try', 974]],
#   2: [[False, 3020]],
#   3: [['False', 2652], ['Break big rock', 368]],
#   4: [['False', 788], ['Something', 2232]],
#   5: [['False', 39], ['Something', 1958], ['Big rocks', 851]],
#   6: [['False', 188], ['Something', 963], ['Big rocks', 1869]],
#   7: [['False', 90], ['Big rocks', 763], ['Something', 633]],
#   8: [['False', 419], ['Something', 951], ['Big rocks', 1013]]},
#  4093: {1: [[False, 3020]],
#   2: [[False, 3020]],
#   3: [[False, 2575]],
#   4: [[False, 3020]],
#   5: [[False, 2075]],
#   6: [[False, 1908]],
#   7: [[False, 2007]],
#   8: [[False, 2407]]},
#  4094: {1: [[False, 3020]],
#   2: [['False', 2], ['remove large rock top', 3018]],
#   3: [['False', 2], ['remove large rock top', 1433]],
#   4: [['False', 48], ['remove large rock top', 1397]],
#   5: [['False', 2], ['brown rock top', 3018]],
#   6: [['False', 3], ['small rock top', 296], ['brown rock top', 2721]],
#   7: [['False', 3], ['small rock top', 353], ['brown rock top', 2664]],
#   8: [['False', 3],
#    ['small rock top', 1184],
#    ['remove large rock top', 1833]]},
#  4095: {1: [[False, 3020]],
#   2: [['False', 505], ['Breaking large rock pile', 2515]],
#   3: [['False', 2], ['Breaking large rock pile', 3018]],
#   4: [['False', 2247], ['Breaking large rock pile', 773]],
#   5: [[False, 3020]],
#   6: [[False, 2318]],
#   7: [[False, 2395]],
#   8: [[False, 2275]]},
#  4096: {1: [[False, 3020]],
#   2: [['False', 2019], ['Pick up small and large', 1001]],
#   3: [['False', 5],
#    ['Pick up large on victim', 70],
#    ['Pick up small and large', 2163],
#    ['Pick up small on victim', 427]],
#   4: [['False', 6],
#    ['Pick up large on victim', 92],
#    ['Pick up small on victim', 402],
#    ['Pick up small top', 811],
#    ['Pick up small and large', 1709]],
#   5: [['False', 60],
#    ['Pick up small top', 2137],
#    ['Pick up small and large', 823]],
#   6: [['False', 1871],
#    ['Pick up small top', 3],
#    ['Pick up small rock victim', 413]],
#   7: [['False', 61],
#    ['Pick up small rock victim', 2],
#    ['Pickup small top rocks', 1526],
#    ['Remove large rocks victim', 1431]],
#   8: [['False', 405],
#    ['Pickup small top rocks', 3],
#    ['Pick up large rocks left', 1931],
#    ['Stand still', 666]]},
#  4097: {1: [[False, 3020]],
#   2: [[False, 3020]],
#   3: [['False', 1416], ['Large rock', 1604]],
#   4: [['False', 2], ['Large rock', 3018]],
#   5: [['False', 260], ['Label', 2760]],
#   6: [['False', 7],
#    ['Label', 2],
#    ['Large rock', 1],
#    ['1', 1],
#    ['brown rock', 1],
#    ['3', 3008]],
#   7: [['False', 49], ['3', 905], ['Label', 127], ['brown rock', 1939]],
#   8: [['False', 15], ['brown rock', 701], ['Large rock', 2304]]},
#  4098: {1: [['False', 2879], ['Handle large rocks before smash', 141]],
#   2: [['False', 2531],
#    ['Wait for human before break', 348],
#    ['Handle large rocks before smash', 141]],
#   3: [['False', 1869],
#    ['Handle large rocks before smash', 291],
#    ['Wait for human before break', 149]],
#   4: [['False', 1540],
#    ['Move small rocks off large rocks', 463],
#    ['Wait for human before break', 342],
#    ['Unstack large rocks', 668]],
#   5: [['False', 5],
#    ['Move small rocks off large rocks', 409],
#    ['Wait for human before break', 429],
#    ['Unstack large rocks', 326]],
#   6: [['False', 5],
#    ['Move small rocks off large rocks', 224],
#    ['Unstack large rocks', 769],
#    ['Wait for human before break', 27]],
#   7: [['False', 7],
#    ['Move small rocks off large rocks', 523],
#    ['Prevent brown guillotine', 1378],
#    ['Wait for human before break', 1112]],
#   8: [['False', 1087],
#    ['Move small rocks off large rocks', 282],
#    ['Unstack large rocks', 442],
#    ['Wait for human before break', 116]]},
#  4099: {1: [['False', 2846], ['BreakBigTop', 174]],
#   2: [['False', 610],
#    ['BreakBigTop', 83],
#    ['PickBigTop', 225],
#    ['PickUpMultipleSmall', 934]],
#   3: [['False', 3], ['PickUpMultipleSmall', 529], ['PickBigTop', 1150]],
#   4: [['False', 3], ['PickBigTop', 705], ['PickUpMultipleSmall', 618]],
#   5: [['False', 1271],
#    ['PickUpMultipleSmall', 126],
#    ['RemoveBigLeftSide', 1623]],
#   6: [['False', 705],
#    ['PickUpMultipleSmall', 366],
#    ['PickBigTop', 1564],
#    ['PickTop', 385]],
#   7: [['False', 817], ['PickUpSmall', 832], ['PickUpLarge', 440]],
#   8: [['False', 1028], ['PickUpSmall', 493], ['GuidedPickUp', 1156]]}}

# %%
data = {}
cps_used = 0

for participant, rounds in cp_execution.items():
    for round_num, round_data in rounds.items():

        cp_candidates = [
            cp
            for i in range(1, round_num + 1)
            for cp in all_cp_messages[participant][i]
        ]

        for round_data_ in round_data:
            cp_name, ticks = round_data_[0], round_data_[1]
            if cp_name not in ["False", "false", False, None]:

                # Get the latest cp_candidate with the same cp_name
                for cp_candidate in cp_candidates[::-1]:
                    if cp_name in list(cp_candidate.values()):
                        # print(cp_candidate) 
                        break
                        
                cps_used += 1
                # print(f"Participant: {participant}, Round: {round_num}")
                # print(f"cp_name: {cp_name}, ticks: {ticks}")
                # print("cp_used: ", cps_used)
                # print()
                cp_candidate["ticks_lasted"] = ticks
                cp_candidate["cp_name"] = cp_name

                if participant not in data:
                    data[participant] = {}

                if round_num not in data[participant]:
                    data[participant][round_num] = [cp_candidate]
                else:
                    data[participant][round_num].append(cp_candidate)

data
# Out:
# {4069: {3: [{'cp_edit': 'Label',
#     'situation': [],
#     'actionA': [['Human',
#       'Stand still in',
#       'location',
#       'Left',
#       'side of field']],
#     'actionB': [['Break', 'object', 'in', 'location', 'Brown rock']],
#     'postsitu': [],
#     'ticks_lasted': 117,
#     'cp_name': 'Label'}]},
#  4073: {2: [{'cp_edit': 'Small rocks on top',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile',
#       'Small rock'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'actionB': [['Stand still in', 'location', 'Right', 'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 2470,
#     'cp_name': 'Small rocks on top'}],
#   3: [{'cp_edit': 'Large rocks on top',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Human',
#       'Stand still in',
#       'location',
#       'Left',
#       'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 546,
#     'cp_name': 'Large rocks on top'},
#    {'cp_edit': 'Small rocks on top',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile',
#       'Small rock'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'actionB': [['Stand still in', 'location', 'Right', 'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 2470,
#     'cp_name': 'Small rocks on top'}],
#   4: [{'cp_new': 'Large rock on top V2',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Right',
#       'side of field',
#       'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 284,
#     'cp_name': 'Large rock on top V2'}],
#   5: [{'cp_edit': 'small rocks on top V2',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Left',
#       'side of rock pile',
#       'Small rock']],
#     'actionB': [['Stand still in', 'location', 'Right', 'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 744,
#     'cp_name': 'small rocks on top V2'}],
#   6: [{'cp_edit': 'small rocks on top V2',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Left',
#       'side of rock pile',
#       'Small rock']],
#     'actionB': [['Stand still in', 'location', 'Right', 'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 744,
#     'cp_name': 'small rocks on top V2'},
#    {'cp_edit': 'brown rock and small rocks on top',
#     'situation': ['Brown rock', 'Small rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile'],
#      ['Move back and forth in', 'location', 'Right', 'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 2273,
#     'cp_name': 'brown rock and small rocks on top'}],
#   7: [{'cp_edit': 'brown rock on top',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Brown rock',
#       'Top of rock pile',
#       'Pick up',
#       'object',
#       'in',
#       'location'],
#      ['Right',
#       'side of field',
#       'Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock']],
#     'postsitu': [],
#     'ticks_lasted': 2047,
#     'cp_name': 'brown rock on top'}],
#   8: [{'cp_edit': 'brown rock on top',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Top of rock pile',
#       'Brown rock',
#       'Pick up',
#       'object',
#       'in',
#       'location'],
#      ['Right',
#       'side of field',
#       'Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock']],
#     'postsitu': [],
#     'ticks_lasted': 282,
#     'cp_name': 'brown rock on top'},
#    {'cp_edit': 'large rocks on top V4',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 718,
#     'cp_name': 'large rocks on top V4'},
#    {'cp_edit': 'large rocks on top V5',
#     'situation': ['Top of rock pile',
#      'Large rock',
#      'Brown rock',
#      'Small rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Large rock',
#       'Top of rock pile',
#       'Pick up',
#       'object',
#       'in',
#       'location'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 896,
#     'cp_name': 'large rocks on top V5'}]},
#  4081: {1: [{'cp_edit': 'top large',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 330,
#     'cp_name': 'top large'}],
#   2: [{'cp_edit': 'top large',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 330,
#     'cp_name': 'top large'}],
#   3: [{'cp_edit': 'top large',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 330,
#     'cp_name': 'top large'}],
#   4: [{'cp_edit': 'top large',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 330,
#     'cp_name': 'top large'}],
#   5: [{'cp_edit': 'top large',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 330,
#     'cp_name': 'top large'}],
#   6: [{'cp_edit': 'top brown',
#     'situation': ['Top of rock pile', 'Brown rock'],
#     'actionA': [['Stand still in', 'location', 'Above rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Right',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 1917,
#     'cp_name': 'top brown'},
#    {'cp_new': 'top brown test',
#     'situation': ['Brown rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Above rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'On top of',
#       'Object',
#       'Large rock'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Right',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 821,
#     'cp_name': 'top brown test'}],
#   7: [{'cp_edit': 'top brown test',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [['Stand still in', 'location', 'Top of rock pile']],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 3018,
#     'cp_name': 'top brown test'}],
#   8: [{'cp_edit': 'top brown',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 2114,
#     'cp_name': 'top brown'},
#    {'cp_new': 'large below',
#     'situation': ['Large rock', 'On top of', 'Object', 'Small rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'On top of',
#       'Object',
#       'Small rock'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 543,
#     'cp_name': 'large below'}]},
#  4082: {1: [{'cp_new': 'Remove big rock',
#     'situation': ['Right', 'side of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 286,
#     'cp_name': 'Remove big rock'}],
#   2: [{'cp_new': 'Remove large rock top',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 52,
#     'cp_name': 'Remove large rock top'},
#    {'cp_new': 'Remove big rock',
#     'situation': ['Right', 'side of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 286,
#     'cp_name': 'Remove big rock'}],
#   3: [{'cp_new': 'Remove large rock top',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 52,
#     'cp_name': 'Remove large rock top'},
#    {'cp_new': 'Remove big rock',
#     'situation': ['Right', 'side of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 286,
#     'cp_name': 'Remove big rock'}],
#   4: [{'cp_new': 'Remove big rock',
#     'situation': ['Right', 'side of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 286,
#     'cp_name': 'Remove big rock'},
#    {'cp_new': 'Remove large rock top',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 52,
#     'cp_name': 'Remove large rock top'}],
#   5: [{'cp_new': 'Remove big rock',
#     'situation': ['Right', 'side of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 286,
#     'cp_name': 'Remove big rock'},
#    {'cp_new': 'Remove big rock',
#     'situation': ['Right', 'side of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 286,
#     'cp_name': 'Remove big rock'}],
#   6: [{'cp_edit': 'Remove brown rock at top',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 3018,
#     'cp_name': 'Remove brown rock at top'}],
#   7: [{'cp_edit': 'Brown rock',
#     'situation': ['Right', 'side of rock pile', 'Brown rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 2779,
#     'cp_name': 'Brown rock'},
#    {'cp_new': 'Remove large rock top',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 52,
#     'cp_name': 'Remove large rock top'},
#    {'cp_new': 'Large rock on human',
#     'situation': ['Bottom of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Bottom of rock pile',
#       'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 66,
#     'cp_name': 'Large rock on human'}],
#   8: [{'cp_edit': 'Brown rock and small rocks',
#     'situation': ['Top of rock pile', 'Brown rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'On top of',
#       'Object']],
#     'postsitu': [],
#     'ticks_lasted': 2581,
#     'cp_name': 'Brown rock and small rocks'},
#    {'cp_new': 'Remove big rock',
#     'situation': ['Right', 'side of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 286,
#     'cp_name': 'Remove big rock'},
#    {'cp_new': 'Remove large rock top',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Left', 'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 52,
#     'cp_name': 'Remove large rock top'}]},
#  4083: {3: [{'cp_new': 'Decent',
#     'situation': ['Top of rock pile',
#      'Large rock',
#      'Bottom of rock pile',
#      'Large rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Right',
#       'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Left',
#       'side of field',
#       'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 932,
#     'cp_name': 'Decent'}],
#   4: [{'cp_edit': 'Good',
#     'situation': ['Top of rock pile',
#      'Large rock',
#      'Bottom of rock pile',
#      'Large rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Right',
#       'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Left',
#       'side of field',
#       'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 104,
#     'cp_name': 'Good'}],
#   5: [{'cp_new': 'Only small rocks',
#     'situation': ['Small rock', 'Top of rock pile'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'actionB': [['Small rock',
#       'Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 371,
#     'cp_name': 'Only small rocks'},
#    {'cp_edit': 'Good',
#     'situation': ['Top of rock pile',
#      'Large rock',
#      'Bottom of rock pile',
#      'Large rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Right',
#       'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Left',
#       'side of field',
#       'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 104,
#     'cp_name': 'Good'}],
#   6: [{'cp_new': 'Brown rock on top',
#     'situation': ['Top of rock pile', 'Brown rock'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Bottom of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 3018,
#     'cp_name': 'Brown rock on top'}],
#   7: [{'cp_new': 'Do something when only big rock',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 225,
#     'cp_name': 'Do something when only big rock'},
#    {'cp_edit': 'Brown rock on top',
#     'situation': ['Top of rock pile',
#      'Brown rock',
#      'Bottom of rock pile',
#      'Large rock'],
#     'actionA': [],
#     'actionB': [['Large rock',
#       'Pick up',
#       'object',
#       'in',
#       'location',
#       'Bottom of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 2596,
#     'cp_name': 'Brown rock on top'}],
#   8: [{'cp_new': 'Only small rocks',
#     'situation': ['Small rock', 'Top of rock pile'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'actionB': [['Small rock',
#       'Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 371,
#     'cp_name': 'Only small rocks'},
#    {'cp_edit': 'Brown rock on top',
#     'situation': ['Top of rock pile',
#      'Brown rock',
#      'Bottom of rock pile',
#      'Large rock'],
#     'actionA': [],
#     'actionB': [['Large rock',
#       'Pick up',
#       'object',
#       'in',
#       'location',
#       'Bottom of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 953,
#     'cp_name': 'Brown rock on top'},
#    {'cp_new': 'Do something when only big rock',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 225,
#     'cp_name': 'Do something when only big rock'}]},
#  4085: {2: [{'cp_new': 'large rock robot ',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 305,
#     'cp_name': 'large rock robot '}],
#   3: [{'cp_new': 'large rock robot ',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 305,
#     'cp_name': 'large rock robot '}],
#   4: [{'cp_new': 'large rock robot ',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 305,
#     'cp_name': 'large rock robot '},
#    {'cp_new': 'Robot large then small on top',
#     'situation': ['Bottom of rock pile', 'Small rock'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field'],
#      ['Pick up', 'object', 'in', 'location', 'Small rock', 'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Right',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 2712,
#     'cp_name': 'Robot large then small on top'}],
#   6: [{'cp_edit': 'large rock robot ',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 25,
#     'cp_name': 'large rock robot '}],
#   7: [{'cp_edit': 'large rock robot ',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 25,
#     'cp_name': 'large rock robot '}]},
#  4086: {1: [{'cp_edit': 'Large rock on top of pile',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Top of rock pile'],
#      ['Move to', 'Object', 'Large rock']],
#     'actionB': [['Move to', 'Location', 'Top of rock pile'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'On top of',
#       'Actor',
#       'Human'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 913,
#     'cp_name': 'Large rock on top of pile'},
#    {'cp_edit': 'Breaking large rocks',
#     'situation': ['Large rock'],
#     'actionA': [['Move to', 'Object', 'Large rock']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'On top of',
#       'Actor',
#       'Human']],
#     'postsitu': [],
#     'ticks_lasted': 868,
#     'cp_name': 'Breaking large rocks'}],
#   2: [{'cp_edit': 'Breaking large rocks',
#     'situation': ['Large rock'],
#     'actionA': [['Move to', 'Object', 'Large rock']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'On top of',
#       'Actor',
#       'Human']],
#     'postsitu': [],
#     'ticks_lasted': 2753,
#     'cp_name': 'Breaking large rocks'},
#    {'cp_edit': 'Large rock on top of pile',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Top of rock pile'],
#      ['Move to', 'Object', 'Large rock']],
#     'actionB': [['Move to', 'Location', 'Top of rock pile'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'On top of',
#       'Actor',
#       'Human'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 3018,
#     'cp_name': 'Large rock on top of pile'}],
#   3: [{'cp_edit': 'Large rock on top of pile',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [['Stand still in', 'location', 'Top of rock pile'],
#      ['Move to', 'Object', 'Large rock']],
#     'actionB': [['Move to', 'Location', 'Top of rock pile'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'On top of',
#       'Actor',
#       'Human'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 3018,
#     'cp_name': 'Large rock on top of pile'}],
#   4: [{'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Move to', 'Location', 'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 2095,
#     'cp_name': 'Large rock in top of pile'}],
#   5: [{'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Move to', 'Location', 'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 250,
#     'cp_name': 'Large rock in top of pile'},
#    {'cp_edit': 'Label',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Victim'],
#     'actionA': [['Move to', 'Actor', 'Victim']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 272,
#     'cp_name': 'Label'}],
#   6: [{'cp_edit': 'Rock on the left side of the victim',
#     'situation': ['Large rock', 'Left', 'side of field'],
#     'actionA': [['Move to', 'Actor', 'Victim'],
#      ['Move to', 'Location', 'Left', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Victim'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 3018,
#     'cp_name': 'Rock on the left side of the victim'}],
#   7: [{'cp_edit': 'Rock on the right side of the victim',
#     'situation': ['Large rock', 'Right', 'side of rock pile'],
#     'actionA': [['Move to', 'Actor', 'Victim'],
#      ['Move to', 'Location', 'Right', 'side of rock pile'],
#      ['Move to', 'Location', 'Right', 'side of field']],
#     'actionB': [['Move to', 'Actor', 'Victim'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile'],
#      ['Move to', 'Location', 'Right', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 1110,
#     'cp_name': 'Rock on the right side of the victim'},
#    {'cp_edit': 'Label',
#     'situation': ['Large rock', 'On top of', 'Actor', 'Victim'],
#     'actionA': [['Move to', 'Actor', 'Victim']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 272,
#     'cp_name': 'Label'}],
#   8: [{'cp_edit': 'Rock on the right side of the victim',
#     'situation': ['Large rock', 'Right', 'side of rock pile'],
#     'actionA': [['Move to', 'Actor', 'Victim'],
#      ['Move to', 'Location', 'Right', 'side of rock pile'],
#      ['Move to', 'Location', 'Right', 'side of field']],
#     'actionB': [['Move to', 'Actor', 'Victim'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile'],
#      ['Move to', 'Location', 'Right', 'side of field'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 1110,
#     'cp_name': 'Rock on the right side of the victim'},
#    {'cp_edit': 'Large rock in top of pile',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Move to', 'Location', 'Top of rock pile'],
#      ['Stand still in', 'location', 'Top of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Location', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 26,
#     'cp_name': 'Large rock in top of pile'}]},
#  4087: {2: [{'cp_new': 'Move top large rock',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 183,
#     'cp_name': 'Move'}],
#   3: [{'cp_new': 'Move top small rock',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile',
#       'Small rock'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Right',
#       'side of field',
#       'Small rock']],
#     'postsitu': [],
#     'ticks_lasted': 3018,
#     'cp_name': 'Move top small rock'}],
#   4: [{'cp_new': 'Move top large rock',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 183,
#     'cp_name': 'Move'}],
#   5: [{'cp_new': 'Move top large rock',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 183,
#     'cp_name': 'Move'}],
#   6: [{'cp_new': 'Move top large rock',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 183,
#     'cp_name': 'Move'}],
#   7: [{'cp_new': 'break right rock',
#     'situation': ['Right', 'side of field', 'Human'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 65,
#     'cp_name': 'break right rock'},
#    {'cp_new': 'Move top large rock',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 183,
#     'cp_name': 'Move'}],
#   8: [{'cp_new': 'Move top large rock',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 183,
#     'cp_name': 'Move'}]},
#  4089: {1: [{'cp_new': 'Move top large rock',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 183,
#     'cp_name': 'Move'}],
#   2: [{'cp_edit': 'Break Rock',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Large rock'],
#      ['Break', 'object', 'in', 'location', 'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 812,
#     'cp_name': 'Break Rock'}],
#   3: [{'cp_edit': 'Break Rock',
#     'situation': ['Large rock',
#      'Top of rock pile',
#      'Robot',
#      'Left',
#      'side of field'],
#     'actionA': [],
#     'actionB': [['Move to', 'Location', 'Top of rock pile'],
#      ['Move to', 'Object', 'Large rock'],
#      ['Break', 'object', 'in', 'location', 'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 1154,
#     'cp_name': 'Break Rock'}],
#   4: [{'cp_new': 'Break Big Rock',
#     'situation': ['Top of rock pile',
#      'Large rock',
#      'Robot',
#      'Left',
#      'side of field'],
#     'actionA': [],
#     'actionB': [['Move to', 'Location', 'Top of rock pile'],
#      ['On top of', 'Object', 'Large rock'],
#      ['Break', 'object', 'in', 'location', 'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 1572,
#     'cp_name': 'Break Big Rock'}]},
#  4090: {2: [{'cp_edit': 'Top of the pile',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile',
#       'Small rock']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Actor', 'Human']],
#     'postsitu': [],
#     'ticks_lasted': 1203,
#     'cp_name': 'Top of the pile'}],
#   3: [{'cp_edit': 'Top of the pile',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile',
#       'Small rock']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Actor', 'Human']],
#     'postsitu': [],
#     'ticks_lasted': 1203,
#     'cp_name': 'Top of the pile'},
#    {'cp_edit': 'Top of pile small',
#     'situation': ['Small rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Move to', 'Actor', 'Robot']],
#     'postsitu': [],
#     'ticks_lasted': 905,
#     'cp_name': 'Top of pile small'}],
#   4: [{'cp_edit': 'Top of pile small',
#     'situation': ['Small rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Move to', 'Actor', 'Robot']],
#     'postsitu': [],
#     'ticks_lasted': 905,
#     'cp_name': 'Top of pile small'},
#    {'cp_edit': 'Top of the pile',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile',
#       'Large rock'],
#      ['Move to', 'Actor', 'Human']],
#     'postsitu': [],
#     'ticks_lasted': 792,
#     'cp_name': 'Top of the pile'},
#    {'cp_edit': 'Top of the pile improved',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Actor', 'Human']],
#     'postsitu': [],
#     'ticks_lasted': 1914,
#     'cp_name': 'Top of the pile improved'}],
#   5: [{'cp_edit': 'Top of pile small',
#     'situation': ['Small rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Move to', 'Actor', 'Robot']],
#     'postsitu': [],
#     'ticks_lasted': 905,
#     'cp_name': 'Top of pile small'},
#    {'cp_new': 'Left side big rocks',
#     'situation': ['Large rock', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile'],
#      ['Move to', 'Actor', 'Robot']],
#     'postsitu': [],
#     'ticks_lasted': 545,
#     'cp_name': 'Left side big rocks'}],
#   6: [{'cp_new': 'Left side big rocks',
#     'situation': ['Large rock', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile'],
#      ['Move to', 'Actor', 'Robot']],
#     'postsitu': [],
#     'ticks_lasted': 545,
#     'cp_name': 'Left side big rocks'},
#    {'cp_edit': 'Top of pile small',
#     'situation': ['Small rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Move to', 'Actor', 'Robot']],
#     'postsitu': [],
#     'ticks_lasted': 905,
#     'cp_name': 'Top of pile small'}],
#   7: [{'cp_new': 'Left side big rocks',
#     'situation': ['Large rock', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile'],
#      ['Move to', 'Actor', 'Robot']],
#     'postsitu': [],
#     'ticks_lasted': 545,
#     'cp_name': 'Left side big rocks'},
#    {'cp_edit': 'Top of pile small',
#     'situation': ['Small rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Move to', 'Actor', 'Robot']],
#     'postsitu': [],
#     'ticks_lasted': 905,
#     'cp_name': 'Top of pile small'},
#    {'cp_edit': 'Top of the pile',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile',
#       'Large rock'],
#      ['Move to', 'Actor', 'Human']],
#     'postsitu': [],
#     'ticks_lasted': 261,
#     'cp_name': 'Top of the pile'}],
#   8: [{'cp_new': 'Left side big rocks',
#     'situation': ['Large rock', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile'],
#      ['Move to', 'Actor', 'Robot']],
#     'postsitu': [],
#     'ticks_lasted': 545,
#     'cp_name': 'Left side big rocks'},
#    {'cp_new': 'Brown rocks',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile'],
#      ['Move to', 'Actor', 'Robot']],
#     'postsitu': [],
#     'ticks_lasted': 1636,
#     'cp_name': 'Brown rocks'}]},
#  4091: {2: [{'cp_new': '1',
#     'situation': ['Large rock', 'Robot', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 3018,
#     'cp_name': '3'}],
#   3: [{'cp_edit': '1',
#     'situation': ['Large rock', 'Robot', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 2831,
#     'cp_name': '1'}],
#   4: [{'cp_edit': '1',
#     'situation': ['Large rock', 'Robot', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 1464,
#     'cp_name': '1'}],
#   5: [{'cp_new': '1',
#     'situation': ['Large rock', 'Robot', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 3018,
#     'cp_name': '3'}],
#   6: [{'cp_new': '1',
#     'situation': ['Large rock', 'Robot', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 3018,
#     'cp_name': '3'}],
#   7: [{'cp_edit': '1',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [['Move to', 'Object', 'Small rock']],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 3018,
#     'cp_name': '1'}],
#   8: [{'cp_edit': 'Label',
#     'situation': ['Large rock', 'Robot', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 167,
#     'cp_name': 'Label'},
#    {'cp_edit': '1',
#     'situation': ['Brown rock', 'Top of rock pile'],
#     'actionA': [['Move to', 'Object', 'Small rock']],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 2820,
#     'cp_name': '1'}]},
#  4092: {1: [{'cp_new': 'try',
#     'situation': ['Small rock', 'Top of rock pile'],
#     'actionA': [['Move to', 'Object'],
#      ['Pick up', 'object', 'in', 'location']],
#     'actionB': [['Move to', 'Object'],
#      ['Pick up', 'object', 'in', 'location']],
#     'postsitu': [],
#     'ticks_lasted': 2232,
#     'cp_name': 'Something'}],
#   3: [{'cp_new': 'Break big rock',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Move to', 'Object'], ['Break', 'object', 'in', 'location']],
#     'postsitu': [],
#     'ticks_lasted': 368,
#     'cp_name': 'Break big rock'}],
#   4: [{'cp_new': 'try',
#     'situation': ['Small rock', 'Top of rock pile'],
#     'actionA': [['Move to', 'Object'],
#      ['Pick up', 'object', 'in', 'location']],
#     'actionB': [['Move to', 'Object'],
#      ['Pick up', 'object', 'in', 'location']],
#     'postsitu': [],
#     'ticks_lasted': 2232,
#     'cp_name': 'Something'}],
#   5: [{'cp_edit': 'Something',
#     'situation': ['Small rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Stand still in', 'location', 'Top of rock pile'],
#      ['Pick up', 'object', 'in', 'location', 'Small rock', 'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 951,
#     'cp_name': 'Something'},
#    {'cp_edit': 'Big rocks',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Large rock'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Bottom of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 851,
#     'cp_name': 'Big rocks'}],
#   6: [{'cp_edit': 'Something',
#     'situation': ['Small rock', 'Top of rock pile'],
#     'actionA': [],
#     'actionB': [['Stand still in', 'location', 'Top of rock pile'],
#      ['Pick up', 'object', 'in', 'location', 'Small rock', 'Top of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 951,
#     'cp_name': 'Something'},
#    {'cp_edit': 'Big rocks',
#     'situation': ['Large rock', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Large rock'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 1869,
#     'cp_name': 'Big rocks'}],
#   7: [{'cp_edit': 'Big rocks',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [],
# ...
#     'cp_name': 'brown rock'}],
#   8: [{'cp_edit': 'brown rock',
#     'situation': ['Robot', 'Left', 'side of rock pile'],
#     'actionA': [],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Pick up', 'object', 'in', 'location', 'Brown rock', 'Top of rock pile'],
#      ['Move to', 'Object', 'Left', 'side of rock pile'],
#      ['Drop',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 701,
#     'cp_name': 'brown rock'},
#    {'cp_new': 'Large rock',
#     'situation': ['Large rock', 'Top of rock pile'],
#     'actionA': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 2304,
#     'cp_name': 'Large rock'}]},
#  4098: {1: [{'cp_new': 'Handle large rocks before smash',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Object', 'Small rock'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 291,
#     'cp_name': 'Handle large rocks before smash'}],
#   2: [{'cp_new': 'Wait for human before break',
#     'situation': ['Large rock', 'Right', 'side of rock pile'],
#     'actionA': [['Move to', 'Location', 'Right', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 116,
#     'cp_name': 'Wait for human before break'},
#    {'cp_new': 'Handle large rocks before smash',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Object', 'Small rock'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 291,
#     'cp_name': 'Handle large rocks before smash'}],
#   3: [{'cp_new': 'Handle large rocks before smash',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile'],
#      ['Move to', 'Object', 'Small rock'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 291,
#     'cp_name': 'Handle large rocks before smash'},
#    {'cp_new': 'Wait for human before break',
#     'situation': ['Large rock', 'Right', 'side of rock pile'],
#     'actionA': [['Move to', 'Location', 'Right', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 116,
#     'cp_name': 'Wait for human before break'}],
#   4: [{'cp_new': 'Move small rocks off large rocks',
#     'situation': ['Small rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'On top of',
#       'Object',
#       'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 282,
#     'cp_name': 'Move small rocks off large rocks'},
#    {'cp_new': 'Wait for human before break',
#     'situation': ['Large rock', 'Right', 'side of rock pile'],
#     'actionA': [['Move to', 'Location', 'Right', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 116,
#     'cp_name': 'Wait for human before break'},
#    {'cp_edit': 'Unstack large rocks',
#     'situation': ['Large rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Large rock'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'On top of',
#       'Object',
#       'Large rock',
#       'Large rock'],
#      ['Drop', 'object', 'in', 'location', 'Left', 'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 442,
#     'cp_name': 'Unstack large rocks'}],
#   5: [{'cp_new': 'Move small rocks off large rocks',
#     'situation': ['Small rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'On top of',
#       'Object',
#       'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 282,
#     'cp_name': 'Move small rocks off large rocks'},
#    {'cp_new': 'Wait for human before break',
#     'situation': ['Large rock', 'Right', 'side of rock pile'],
#     'actionA': [['Move to', 'Location', 'Right', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 116,
#     'cp_name': 'Wait for human before break'},
#    {'cp_edit': 'Unstack large rocks',
#     'situation': ['Large rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Large rock'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'On top of',
#       'Object',
#       'Large rock',
#       'Large rock'],
#      ['Drop', 'object', 'in', 'location', 'Left', 'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 442,
#     'cp_name': 'Unstack large rocks'}],
#   6: [{'cp_new': 'Move small rocks off large rocks',
#     'situation': ['Small rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'On top of',
#       'Object',
#       'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 282,
#     'cp_name': 'Move small rocks off large rocks'},
#    {'cp_edit': 'Unstack large rocks',
#     'situation': ['Large rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Large rock'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'On top of',
#       'Object',
#       'Large rock',
#       'Large rock'],
#      ['Drop', 'object', 'in', 'location', 'Left', 'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 442,
#     'cp_name': 'Unstack large rocks'},
#    {'cp_new': 'Wait for human before break',
#     'situation': ['Large rock', 'Right', 'side of rock pile'],
#     'actionA': [['Move to', 'Location', 'Right', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 116,
#     'cp_name': 'Wait for human before break'}],
#   7: [{'cp_new': 'Move small rocks off large rocks',
#     'situation': ['Small rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'On top of',
#       'Object',
#       'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 282,
#     'cp_name': 'Move small rocks off large rocks'},
#    {'cp_new': 'Prevent brown guillotine',
#     'situation': ['Brown rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Brown rock',
#       'On top of',
#       'Object',
#       'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 1378,
#     'cp_name': 'Prevent brown guillotine'},
#    {'cp_new': 'Wait for human before break',
#     'situation': ['Large rock', 'Right', 'side of rock pile'],
#     'actionA': [['Move to', 'Location', 'Right', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 116,
#     'cp_name': 'Wait for human before break'}],
#   8: [{'cp_new': 'Move small rocks off large rocks',
#     'situation': ['Small rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'On top of',
#       'Object',
#       'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 282,
#     'cp_name': 'Move small rocks off large rocks'},
#    {'cp_edit': 'Unstack large rocks',
#     'situation': ['Large rock', 'On top of', 'Object', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Move to', 'Object', 'Large rock'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'On top of',
#       'Object',
#       'Large rock',
#       'Large rock'],
#      ['Drop', 'object', 'in', 'location', 'Left', 'side of field']],
#     'postsitu': [],
#     'ticks_lasted': 442,
#     'cp_name': 'Unstack large rocks'},
#    {'cp_new': 'Wait for human before break',
#     'situation': ['Large rock', 'Right', 'side of rock pile'],
#     'actionA': [['Move to', 'Location', 'Right', 'side of rock pile']],
#     'actionB': [['Move to', 'Actor', 'Human'],
#      ['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Right',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 116,
#     'cp_name': 'Wait for human before break'}]},
#  4099: {1: [{'cp_new': 'BreakBigTop',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 83,
#     'cp_name': 'BreakBigTop'}],
#   2: [{'cp_new': 'BreakBigTop',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Break',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 83,
#     'cp_name': 'BreakBigTop'},
#    {'cp_new': 'PickBigTop',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 1564,
#     'cp_name': 'PickBigTop'},
#    {'cp_new': 'PickUpMultipleSmall',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Pick up', 'object', 'in', 'location', 'Small rock', 'Top of rock pile'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 366,
#     'cp_name': 'PickUpMultipleSmall'}],
#   3: [{'cp_new': 'PickUpMultipleSmall',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Pick up', 'object', 'in', 'location', 'Small rock', 'Top of rock pile'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 366,
#     'cp_name': 'PickUpMultipleSmall'},
#    {'cp_new': 'PickBigTop',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 1564,
#     'cp_name': 'PickBigTop'}],
#   4: [{'cp_new': 'PickBigTop',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 1564,
#     'cp_name': 'PickBigTop'},
#    {'cp_new': 'PickUpMultipleSmall',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Pick up', 'object', 'in', 'location', 'Small rock', 'Top of rock pile'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 366,
#     'cp_name': 'PickUpMultipleSmall'}],
#   5: [{'cp_new': 'PickUpMultipleSmall',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Pick up', 'object', 'in', 'location', 'Small rock', 'Top of rock pile'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 366,
#     'cp_name': 'PickUpMultipleSmall'},
#    {'cp_new': 'RemoveBigLeftSide',
#     'situation': ['Left', 'side of rock pile', 'Brown rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Left',
#       'side of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 1623,
#     'cp_name': 'RemoveBigLeftSide'}],
#   6: [{'cp_new': 'PickUpMultipleSmall',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile'],
#      ['Pick up', 'object', 'in', 'location', 'Small rock', 'Top of rock pile'],
#      ['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 366,
#     'cp_name': 'PickUpMultipleSmall'},
#    {'cp_new': 'PickBigTop',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 1564,
#     'cp_name': 'PickBigTop'},
#    {'cp_new': 'PickTop',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Large rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 385,
#     'cp_name': 'PickTop'}],
#   7: [{'cp_new': 'PickUpSmall',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 493,
#     'cp_name': 'PickUpSmall'},
#    {'cp_new': 'PickUpLarge',
#     'situation': ['Top of rock pile', 'Large rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Top of rock pile',
#       'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 440,
#     'cp_name': 'PickUpLarge'}],
#   8: [{'cp_new': 'PickUpSmall',
#     'situation': ['Top of rock pile', 'Small rock'],
#     'actionA': [],
#     'actionB': [['Pick up',
#       'object',
#       'in',
#       'location',
#       'Small rock',
#       'Top of rock pile']],
#     'postsitu': [],
#     'ticks_lasted': 493,
#     'cp_name': 'PickUpSmall'},
#    {'cp_edit': 'GuidedPickUp',
#     'situation': ['Top of rock pile', 'Brown rock'],
#     'actionA': [['Stand still in',
#       'location',
#       'On top of',
#       'Object',
#       'Large rock']],
#     'actionB': [['Pick up', 'object', 'in', 'location', 'Large rock']],
#     'postsitu': [],
#     'ticks_lasted': 1156,
#     'cp_name': 'GuidedPickUp'}]}}

# %%
import pandas as pd

# Load the CSV file
data = pd.read_csv("./user-data/new/data_aggregate_complete.csv", sep=",")

# Filter the DataFrame to only include rows where Condition == "C3"
filtered_data = data[data["Condition"] == "C3"]

# Initialize the final result dictionary
scores = {}

# Iterate through each row in the filtered DataFrame
for index, row in filtered_data.iterrows():
    participant = row["Participant"]
    roundnr = row["Roundnr"]
    time_score = row["Time_score"]

    # Ensure that the participant exists in the result dictionary
    if participant not in scores:
        scores[participant] = {}
    try:
        # Store the round number and time score in the sub-dictionary
        scores[participant][roundnr] = int(time_score)
    except ValueError:
        print(f"Invalid time score for participant {participant} in round {roundnr}")

# Now 'result' contains the desired dictionary structure
scores  # lower the better
# Out:
# Invalid time score for participant 4091 in round 8
# {4069: {1: 6000,
#   2: 4100,
#   3: 2336,
#   4: 4100,
#   5: 1897,
#   6: 4289,
#   7: 3291,
#   8: 4225},
#  4070: {1: 4400,
#   2: 4200,
#   3: 4200,
#   4: 2003,
#   5: 3339,
#   6: 4500,
#   7: 2229,
#   8: 1640},
#  4073: {1: 4700,
#   2: 6400,
#   3: 5800,
#   4: 3900,
#   5: 4900,
#   6: 6600,
#   7: 5500,
#   8: 5057},
#  4081: {1: 4800, 2: 1270, 3: 887, 4: 1123, 5: 922, 6: 6200, 7: 6700, 8: 6000},
#  4082: {1: 4900,
#   2: 2582,
#   3: 2251,
#   4: 2356,
#   5: 5800,
#   6: 5600,
#   7: 2830,
#   8: 5300},
#  4083: {1: 5100,
#   2: 2630,
#   3: 1355,
#   4: 2857,
#   5: 3900,
#   6: 5400,
#   7: 5700,
#   8: 2237},
#  4085: {1: 4600,
#   2: 1309,
#   3: 1361,
#   4: 4200,
#   5: 2577,
#   6: 4700,
#   7: 1863,
#   8: 4400},
#  4086: {1: 5800,
#   2: 7100,
#   3: 6800,
#   4: 2077,
#   5: 4098,
#   6: 4800,
#   7: 1769,
#   8: 4219},
#  4087: {1: 4400,
#   2: 1598,
#   3: 5600,
#   4: 1313,
#   5: 5700,
#   6: 3553,
#   7: 4900,
#   8: 5900},
#  4089: {1: 4700,
#   2: 5100,
#   3: 3700,
#   4: 2741,
#   5: 3327,
#   6: 3021,
#   7: 3215,
#   8: 3530},
#  4090: {1: 4500,
#   2: 4500,
#   3: 1857,
#   4: 5700,
#   5: 1359,
#   6: 1177,
#   7: 3071,
#   8: 4400},
#  4091: {1: 5300, 2: 3800, 3: 4000, 4: 1774, 5: 6900, 6: 6700, 7: 6800},
#  4092: {1: 5900,
#   2: 3700,
#   3: 3700,
#   4: 5300,
#   5: 2828,
#   6: 4300,
#   7: 1466,
#   8: 2363},
#  4093: {1: 5000,
#   2: 6300,
#   3: 2555,
#   4: 4100,
#   5: 3255,
#   6: 3288,
#   7: 3687,
#   8: 2387},
#  4094: {1: 4900,
#   2: 4500,
#   3: 1415,
#   4: 1425,
#   5: 5900,
#   6: 6100,
#   7: 5700,
#   8: 5300},
#  4095: {1: 4500,
#   2: 6300,
#   3: 6500,
#   4: 4000,
#   5: 4300,
#   6: 3198,
#   7: 3375,
#   8: 3455},
#  4096: {1: 4100,
#   2: 4400,
#   3: 2645,
#   4: 4500,
#   5: 5700,
#   6: 3667,
#   7: 5300,
#   8: 2985},
#  4097: {1: 4200,
#   2: 6200,
#   3: 5400,
#   4: 4700,
#   5: 6000,
#   6: 4900,
#   7: 5400,
#   8: 5200},
#  4098: {1: 3600,
#   2: 3900,
#   3: 2289,
#   4: 3293,
#   5: 2849,
#   6: 2805,
#   7: 4600,
#   8: 2607},
#  4099: {1: 4600,
#   2: 1832,
#   3: 1662,
#   4: 1306,
#   5: 4200,
#   6: 4800,
#   7: 2869,
#   8: 3457}}
